# %% [markdown]
# ### RQ3: Plot the temporal distribution of first and last 10,000 commit messages of random 1000 projects with at least 50,000 commits. Also, perform distribution fitting to finding the best distribution that fits the underlying commit messages at each repository level.

# %%
import pandas as pd
import chardet
import nltk
from nltk.corpus import stopwords
import pickle
import pyarrow.parquet as pq
import numpy
import os
import vaex as vx
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as st
import math
import glob
from scipy.optimize import curve_fit
import time
import random 
from platform import python_version

# %%
# %matplotlib inline

# %% [markdown]
# #### Using VAEX dataframes for larger

# %%
# VAEX DATAFRAME
df= []

# %%
# READ ALL THE PARQUET FILE
df = vx.open('/data/fdac21/eawoc//processed_data/*.parquet')

# %%
# COLUMN NAMES
columns = ["projectID", "commitID", "author", "committer", 
           "authorTime", "committerTime", "authorTimezone", 
           "commitlsterTimezone", "commitMessage"]

# %%
# Review the data
df.head()
# Out:
#   #  projectID        commitID                                  author                                          committer                                         authorTime    committerTime    authorTimezone    committerTimezone  commitMessage
#   0  wildfly_wildfly  00001a1a9d1552584eee5e62ab11d7b86408c0d8  ochaloup <ochaloup@redhat.com>                  ochaloup <ochaloup@redhat.com>                    1488898509       1489149067             +0100                +0100  '[JBTM-2858] adding JAXRS filter to import trans...
#   1  wildfly_wildfly  00010938ae7227834e2c69a9c3c71c95d3f3483d  Stuart Douglas <stuart.w.douglas@gmail.com>     Stuart Douglas <stuart.w.douglas@gmail.com>       1458105079       1458105079             +1100                +1100  WFCORE-1436 Undertow 1.3.19.Final
#   2  wildfly_wildfly  000183c08f9e7d9770ad8216acb565552da7bfb0  Jeff Mesnil <jmesnil@gmail.com>                 Jeff Mesnil <jmesnil@gmail.com>                   1332344580       1332436142             +0100                +0100  '[JBPAPP-8184] Connection factory failure\\n* add...
#   3  wildfly_wildfly  0001a3f7a195b75e563280609636faa249877036  jaikiran <jaikiran.pai@gmail.com>               baranowb <baranowb@gmail.com>                     1328294482       1328611298             +0530                +0100  Upgrade to 2.0.0 of jboss-ejb3-ext-api
#   4  wildfly_wildfly  00024ccfa6fa6fd6426de7bb1d8d494798b384fe  James R. Perkins <jperkins@redhat.com>          GitHub <noreply@github.com>                       1583899415       1583899415             -0700                -0700  'Merge pull request #13102 from kabir/WFLY-13222...
#   5  wildfly_wildfly  0002dbdc7b6cb98e6387cc5f0d11bb93229c5381  Kabir Khan <kkhan@redhat.com>                   GitHub <noreply@github.com>                       1491037874       1491037874             +0100                +0100  'Merge pull request #9883 from jbosstm/WFLY-8485...
#   6  wildfly_wildfly  000325d9bb03ceffbe9e7b4756a5566b273040d1  Brian Stansberry <brian.stansberry@redhat.com>  Brian Stansberry <brian.stansberry@redhat.com>    1503172204       1505862581             -0500                -0500  Minor cleanup
#   7  wildfly_wildfly  0003c4792f52061661cc9db421c7741bc4df8284  Richard Achmatowicz <rachmatowicz@jboss.com>    Paul Ferraro <paul.ferraro@redhat.com>            1370975878       1374591017             -0400                -0400  [WFLY-1430] Add in XML processing, test cases.
#   8  wildfly_wildfly  0004ba7ca70b15a48fe6460ec5375c86cd8dc19d  Scott Marlow <smarlow@redhat.com>               Scott Marlow <smarlow@redhat.com>                 1463689533       1473273893             -0400                -0400  'add org.wildfly.extension.nosql.common dependen...
#   9  wildfly_wildfly  000703aae4a2cc2cc0f1c4a9a03ae391bb76def0  Pelisse Romain <belaran@redhat.com>             GitHub <noreply@github.com>                       1470623929       1470623929             +0000                +0000  'Merge 03a1e02b4aa392ec3d8914846eee615232f45d89 ...

# %%
# list of project names 
project_names = df.projectID.unique()
print(project_names)
# Out:
# ['saqib-ali_hivemined', 'git.kernel.org_pub_scm/public-inbox/vger.kernel.org/linux-media/0', 'RIOT-OS_RIOT', 'trattkantarell_src', 'sahil28297_erpnext', 'ThePiGuy0_android_device_motorola_msm8226-common', 'git.kernel.org_pub_scm/public-inbox/vger.kernel.org/lkml/0', 'jdzs1_b', 'ZIDAN44_linux-stable', 'timhuynh94_231AS', 'Leaflet_Leaflet', 'discourse_discourse', 'gitorious.org_netbeans/main-silver', 'nanoframework_ChibiOS-bkp', 'AnnaLut_abs3', 'civicrm_civicrm-core', 'thomasNDS_lbl', 'gentoo_gentoo', 'neo4j_neo4j', 'maritimerabroad_gitfiti', 'dotnet_aspnetcore', 'geos4s_18S856162', 'learn-co-curriculum_python-for-loops-lab', 'jthub_ega-file-transfer-to-collab-1-jtracker', 'denis-gz_qtbase', 'Alsan_turing-chunk07', 'CRAZYFAKE_handiwork', 'i17c_ecode', 'Reese-D_my_emacs', 'gitlab.com_Ponce_slackbuilds', 'jthub_ega-file-transfer-to-collab-2-jtracker', 'stoupoun_p2-breathe', 'Waffiliate_repoForSynch', 'jthub_ega-file-transfer-to-collab-5-jtracker', 'Arshiamidos_84ck1N617', 'mono_mono', 'appcelerator_titanium_mobile', 'nuvipannu_i-love-github', 'skbkontur_hackathon-2018.1-team20', 'luci_luci-go', 'getsentry_sentry', 'LambdaSchool_Graphs', 'gelstudios_gitfiti', 'marcomep_subversion', 'snapcore_snapd', 'dreamsxin_zabbix', 'SAP_openui5', 'A">', 'Mastermaulik_ofbiz', 'Indicia-Team_drupal-7-module-jquerymobile', 'project-draco-hr_intellij-community', 'K5371_4', 'camille1113_cs126', 'xen-project_xen', 'usukhbayar-boop_PLS', 'laravel_laravel', 'P79N6A_gecko-dev-comments-removed', 'wikimedia_operations-mediawiki-config', '# Fix the conflict (markers are in the file)  Build & Test ', 'JMRI_JMRI', 'ynnsn_weather', 'pandas-dev_pandas', 'repo.or.cz_netbsd-mini2440', 'Securonix_AttackSimulator', 'hasura-imad_imad-2016-app', 'ssbattousai_Cuda14', 'ssbattousai_Cuda13', 'ryanniehaus_open_source_package_builder', 'fink_fink-distributions', 'adhikari18_repo', '5john_5john', 'golang_go', 'ejucovy_megamap-data', 'Ne00n_Hetzner', '123">', 'guadguadt_up', '0xbzho_onename', 'everypolitician-scrapers_belarus-house-of-representatives-2016', 'mkschreder_openwrt-xorg-feed', 'beaulebens_keyring', 'jchampio_gpdb', 'NixOS_nix', 'gitlab.com_quicla_platform/system/netd', 'MyProgrammingStyle_hotspot', 'AdrianDC_aosp_development_sony8960_q', 'gitlab.com_kpld-webrtc_third_party', 'dev-segal_dev-segal.github.io', 'toxtli_deprecated', 'lvotypko_javatest-report', 'Azure_azure-sdk-for-net', 'git.kernel.org_pub_scm/public-inbox/vger.kernel.org/lkml/1', 'php_php-src', 'liu76874151_appsuite-middleware', 'shubhamagarwal1993_Data-Structures', 'redhat-openstack_khaleesi', 'smaslennikov_whattimeisitrightmeow', 'ebezault_EiffelStudio', 'speedtracker_speedtracker', 'Awan_ops', 'edom_eclipse', 'obfuscated_codeblocks_sf', 'scriptzteam_newzNZB-Usenet-Upload-Logger-v1.1', 'drt24_openbsd-import', 'unicode-org_icu', 'devkitPro_newlib', '0xrabin_commitsbro', 'racket_racket', 'MonetDB_MonetDB', 'ledyba_This_World_is_Empty', 'cockroachdb_cockroach', 'licshire_public-buildpacks-ci-robots', 'jasoncalabrese_indy-e4b', 'enkidevs_commit', 'ssbattousai_Cuda37', 'openbsd-unofficial_openbsd-src', 'anongit.kde.org_calligra', 'sbmlteam_sbml-test-suite', 'scriptzteam_BitCoin-MemPool-Fees-v.1.1', 'wertklop_intellij-community', 'nodejs_node', 'pohly_chromiumos-overlays-board-overlays', 'IIJ-NetBSD_netbsd-src', 'jasoncalabrese_indy2d', 'marco-c_gecko-dev-wordified-and-comments-removed', 'libuv_libuv', 'ssbattousai_Cuda36', 'bitpay_bitcore', 'dolphin-emu_dolphin', 'frankbaele_temp', 'gitlab.com_quicla_kernel/lk', 'git.kernel.org_pub_scm/public-inbox/vger.kernel.org/lkml/3', 'git.kernel.org_pub_scm/public-inbox/vger.kernel.org/netdev/0', 'DOCGroup_ACE_TAO', 'ssbattousai_Cuda15', 'apache_jmeter', 'dotnet_roslyn', 'Homebrew_homebrew', 'git.kernel.org_pub_scm/public-inbox/vger.kernel.org/stable/0', 'linux-mailinglist-archives_linux-kernel.vger.kernel.org.1', 'wikimedia_integration-config', 'hashicorp_terraform', 'joyent_pkgsrc-legacy', 'gentoo_sci', 'audacity_audacity', 'sjqtentacles_github-autocommit', 'Ho ...

# %% [markdown]
# ### [3] Plot the temporal distribution of first and last 10,000 commit messages of random 1000 projects with at least 50,000 commits. Also, perform distribution fitting to finding the best distribution that fits the underlying commit messages at each repository level.

# %%
# Use the df data frame for the analysis from above. The commitMessage column contains all the 
# text of the projects. Recommended to work on a smaller sample of commitMessage first. 
# 1. from df select a random project and extract committerTime, sort in the increasing order. 
# Take the first 10k and the last 10k message for plotting.

# %%
v = df.projectID.value_counts()

# %%
cans = df[df.projectID.isin(v.index[v.gt(50000)])]
cans = cans.projectID.unique()

# %%
random.seed(100)
projects = random.sample(cans, 1000)
print(projects)
# Out:
# ['ruby_ruby', 'learn-co-students_activerecord-crud-v-000', 'keum_data_display', 'struan_netherlands', 'geovas01_man4', 'doctorjei_pidgin', 'gitlab.com_quicla_platform/tools/test/connectivity', 'chuan12_shenzhouzd', 'State-College-Plone_Products.IstTheme', 'llvm-project_llvm-project-ng', 'bioconda_bioconda-recipes', 'google-test_signcla-probe-repo', 'git.kernel.org_pub_scm/public-inbox/vger.kernel.org/lkml/5', 'pequet_public-logs', 'scriptzteam_newzNZB-Usenet-Upload-Logger-v1.1', 'apple_llvm-project-v5-split', 'Door43_d43-en', 'kanzure_brlcad', 'bahmedraaz_myProjectOpenAps', 'ARMmbed_DAPLink', 'Sarybe_ThumbnailTooltip', 'moiify_AutoGreen', '8irder_heartinternetstatus', 'flushbeer_waka', 'surli_backup-experiments', 'teku45_Web-DROP', 'infinit_elle', 'johame_w00t', 'ingenue_hunter-cache', 'git.eclipse.org_r_tracecompass/org.eclipse.tracecompass', 'project-draco-hr_liferay-portal', 'earl-ducaine_brl-cad-svn-follow', 'GregorStocks_0.1', 'acquia_blt', 'discourse_discourse', 'roschina_rosdoc_tag_index', 'tencentyun_qcloud-documents', 'ilikeavocadoes_productivity', 'sourceconnect-tests_subscription', 'alpinelinux_aports', 'usukhbayar-boop_PLS', 'spring-projects_spring-boot', 'MycroftAI_mycroft-core', 'makersacademy_airport_challenge', 'majesty86_phase-0-tracks', 'licshire_public-buildpacks-ci-robots', 'Tiseg_github-slideshow', 'jkim664_junik', 'apache_hbase', 'pawohl_studip', 'gitorious.org_wxfork/wxwidgets', 'star-bnl_star-sw', 'jthub_ega-file-transfer-to-collab-3-jtracker', 'evileval_wooyun-image-2015', 'haiku_haiku', 'gitlab.com_quicla_kernel/lk', 'sujaypat_cs225', 'ahf_tor-jenkins', 'tmtmtmtm_mexico-diputados-2015', 'commit-b0t_commit-b0t', 'cirosantilli_test-many-commits-1m', 'ngriffin7a_icefaces4-trunk', 'rust-lang_rust', 'SockPuppetry_Loop-A', 'gspu_vbox', 'rathena_rathena', 'jasoncalabrese_indy2d', 'raytapan_mgm-ice-R22', 'rubygems_rubygems', 'openbsd-unofficial_openbsd-src', 'gitlab.com_szzdlab_djy', 'ocaml_opam-bulk-logs', 'racket_racket', 'jh3y_pic', 'hashibiroko_tanoshi', 'brianchandotcom_liferay-portal', 'greedyboy_blogBak', 'mikemcqueen_WordGameClues', 'suzutan0s2_contribution-calender', 'Alsan_turing-chunk07', 'godotengine_godot', 'tmtmtmtm_philippines-house-of-representatives', 'gitlab.com_quicla_platform/packages/apps/Settings', 'mozillazg_pypy', 'LibreELEC_LibreELEC.tv', 'liu76874151_appsuite-middleware', 'g0v-data_mirror-minutely', 'firemodels_fds', 'TheMattSykes_personal-website', 'OSGeo_grass-legacy', 'PrestaShop_PrestaShop', 'gitlab.com_quicla_platform/system/netd', 'aws-aemilia_CanaryTestOnly-DoNotTouch-ap-east-1', 'wmshort_latinwordnet-archive', 'devkitPro_newlib', 'EricLindemann_CSCI-4308-Open-Sources-Data-Analytics', 'edom_eclipse', 'NgoMike_gitfiti', 'cirosantilli_imagine-all-the-people', 'qooxdoo_qooxdoo', 'pcheng11_RainGame', 'openssl_openssl', 'ofiwg_libfabric', 'szeder_all-git-forks', 'hannesmuehleisen_MonetDBLite-C', 'jadonk_bonescript', 'roytam1_mozilla-cvs-history-subtree', 'wikimedia_integration-config', 'AlfrescoTestAutomation_alfresco-desktopsync', 'mkschreder_openwrt-xorg-feed', 'openstack_openstack', 'sourcemage_grimoire', 'Wadauk_scihub_ck', 'pbaffiliatetwoop_testRepository', 'repo.or.cz_tails', 'mtn_cocoa-eh-hugo-theme', 'bio-repo_ncbi_cpp_toolkit', 'topcoder-platform_tc-online-review', 'ballerina-platform_ballerina-lang', 'mad-science_18135', 'Plailect_Guide_3DS', 'google_angle', 'pars-linux_corporate2', 'rossabaker_abolish-ice', 'xbmc_xbmc', 'sourceconnect-testing_reposync', 'ChristopheDucamp_christopheducamp.github.io', 'trilinos_Trilinos', 'BOINC_boinc', 'tmtmtmtm_romanian-parliament', 'MariusCiocanel_0.0', 'demisto_content', 'qemu_edk2', 'regro_repodata-shards', 'xanderself_one-million-commit', 'infaautovcs_DependencyUIAuto', 'mquinson_PLM-data', 'obfuscated_codeblocks_sf', 'istio_istio', 'xwvvvvwx_untrustix-git-testdata', 'Indicia-Team_drupal-7-module-jquerymobile', 'SSWConsulting_SSW.Rules', 'mozilla_gecko-dev', 'android.googlesource.com_platform_external/qemu', 'RIOT-OS_RIOT', 'oqeerbfo ...

# %%
from fitter import Fitter, get_common_distributions, get_distributions

# %%
#example distribution
commits = df[df['projectID'] == 'devkitPro_newlib']['committerTime'].to_numpy().astype(int)
data = commits
f = Fitter(data,
           distributions= get_common_distributions())
f.fit()
f.summary()
# Out:
#           sumsquare_error          aic           bic    kl_div
# cauchy       7.904308e-17  4368.139867 -7.500731e+06  0.203309
# rayleigh     1.158239e-16          inf -7.442261e+06  0.466524
# norm         1.311430e-16  4314.180206 -7.423252e+06  0.312046
# powerlaw     1.710880e-16  4123.408293 -7.382551e+06  0.834288
# uniform      1.787594e-16  4121.230926 -7.375851e+06  0.902087

# %%
f.get_best(method='sumsquare_error')
# Out:
# {'cauchy': {'loc': 1498617503.8003387, 'scale': 82670833.99347925}}

# %%
dists = []
for project in projects:
    print(project)
    commits = df[df['projectID'] == project]\
                            ['committerTime'].to_numpy()
    commits = commits[commits != numpy.array(None)]
    commits = commits.astype(int)
    f = Fitter(commits,
           distributions= get_common_distributions(), timeout=120)
    f.fit()
    #f.summary()
    best = f.get_best(method='sumsquare_error')
    dists.append(best)
    print(best)
# Out:
# ruby_ruby
# {'norm': {'loc': 1357944183.0969098, 'scale': 150970106.01606458}}
# learn-co-students_activerecord-crud-v-000
# {'rayleigh': {'loc': 1503045952.8364697, 'scale': 33059632.21134094}}
# keum_data_display
# {'powerlaw': {'a': 1.382209761887796, 'loc': 1395731931.1884315, 'scale': 123594388.15196946}}
# struan_netherlands
# {'powerlaw': {'a': 2.0630592835397863, 'loc': 1441783900.8565092, 'scale': 95739288.14350957}}
# geovas01_man4
# {'powerlaw': {'a': 0.26666864279136393, 'loc': -1.5318455998867464e-18, 'scale': 1761953656.5827894}}
# doctorjei_pidgin
# {'cauchy': {'loc': 1197764444.857496, 'scale': 71631828.47988464}}
# gitlab.com_quicla_platform/tools/test/connectivity
# {'rayleigh': {'loc': 1448823135.6753025, 'scale': 70543758.05180852}}
# chuan12_shenzhouzd
# {'exponpow': {'b': 0.8840325950059011, 'loc': 1523886659.9999995, 'scale': 54570957.73085578}}
# State-College-Plone_Products.IstTheme
# {'norm': {'loc': 1274416025.6351597, 'scale': 39141723.828055024}}
# llvm-project_llvm-project-ng
# {'powerlaw': {'a': 1.9929604198083912, 'loc': 979846437.7658267, 'scale': 559540945.2341737}}
# bioconda_bioconda-recipes
# {'powerlaw': {'a': 1.4148867857068903, 'loc': 1442049722.36128, 'scale': 172216621.6387503}}
# google-test_signcla-probe-repo
# {'powerlaw': {'a': 0.818969840045028, 'loc': 1501104617.9999995, 'scale': 113027207.69453453}}
# git.kernel.org_pub_scm/public-inbox/vger.kernel.org/lkml/5
# {'powerlaw': {'a': 1.2366973475219596, 'loc': 1470185911.2658627, 'scale': 47284865.66862709}}
# pequet_public-logs
# {'powerlaw': {'a': 1.001647468629879, 'loc': 1558120062.8059883, 'scale': 53221126.19409621}}
# scriptzteam_newzNZB-Usenet-Upload-Logger-v1.1
# {'rayleigh': {'loc': 1537468735.291743, 'scale': 17212354.20332072}}
# apple_llvm-project-v5-split
# WARNING:root:SKIPPED cauchy distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED chi2 distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED powerlaw distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED gamma distribution (taking more than 120 seconds)
# {'norm': {'loc': 1375835860.8278854, 'scale': 123103947.67120199}}
# Door43_d43-en
# {'gamma': {'a': 11.626481300498114, 'loc': 1383763502.7093096, 'scale': 5890024.881374162}}
# kanzure_brlcad
# {'powerlaw': {'a': 2.0629340508962946, 'loc': 341911410.78595746, 'scale': 1123362245.2140431}}
# bahmedraaz_myProjectOpenAps
# {'norm': {'loc': 1556699632.902388, 'scale': 4193246.5815624767}}
# ARMmbed_DAPLink
# {'norm': {'loc': 1519523247.1482966, 'scale': 50256037.94041998}}
# Sarybe_ThumbnailTooltip
# {'cauchy': {'loc': 1354562895.2862468, 'scale': 30016704.63499154}}
# moiify_AutoGreen
# {'gamma': {'a': 52954.24718899696, 'loc': -378416296.2789969, 'scale': 37367.97130367602}}
# 8irder_heartinternetstatus
# {'cauchy': {'loc': 1376851425.5417626, 'scale': 5695204.585204914}}
# flushbeer_waka
# {'cauchy': {'loc': 1437538894.607642, 'scale': 3170.6220453245096}}
# surli_backup-experiments
# {'norm': {'loc': 1463838185.139818, 'scale': 92775629.43746024}}
# teku45_Web-DROP
# {'powerlaw': {'a': 1.1285917004331565, 'loc': 1469456792.7935705, 'scale': 6050930.315322407}}
# infinit_elle
# {'norm': {'loc': 1463907797.644049, 'scale': 82155607.0829434}}
# johame_w00t
# {'uniform': {'loc': 1528590174.0, 'scale': 1089.0}}
# ingenue_hunter-cache
# {'norm': {'loc': 1497900607.4893842, 'scale': 20897585.505828943}}
# git.eclipse.org_r_tracecompass/org.eclipse.tracecompass
# {'gamma': {'a': 229.70191254229343, 'loc': 699381399.7455783, 'scale': 3439252.893598916}}
# project-draco-hr_liferay-portal
# {'powerlaw': {'a': 3.713784444162428, 'loc': 1031744223.0585108, 'scale': 445739828.0744717}}
# earl-ducaine_brl-cad-svn-follow
# {'cauchy': {'loc': 1291321058.7910671, 'scale': 142026739.08035153}}
# GregorStocks_0.1
# {'powerlaw': {'a': 2.169739962168004, 'loc': 1350012371.4154782, 'scale': 264506208.58452213}}
# acquia_blt
# {'gamma': {'a': 13220.61257172878, 'loc': -6371732715.630663, 'scale': 591114.6295475948}}
# discourse_discourse
# {'powerlaw': {'a': 0.9033549326534653, 'loc': 1360091810.9999998, 'scale': 257658473.2690373}}
# roschina_rosdoc_tag_index
# {'gamma': {'a': 1.7535247259117432, 'loc': 1348277119.8054395, 'scale': 16305510.59014951}}
# tencentyun_qcloud-documents
# {'powerlaw': {'a': 1.8553756970475543, 'loc': 1467737721.7797956, 'scale': 147896104.22020733}}
# ilikeavocadoes_productivity
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# {'uniform': {'loc': 1.0, 'scale': 2147483400.0}}
# sourceconnect-tests_subscription
# {'powerlaw': {'a': 1.5489077815005896, 'loc': 1511216726.5199952, 'scale': 71345969.48000479}}
# alpinelinux_aports
# {'powerlaw': {'a': 2.82067978129459, 'loc': 1135911628.6279573, 'scale': 479721171.37204885}}
# usukhbayar-boop_PLS
# {'gamma': {'a': 8.424547720566022, 'loc': 1426300727.5097737, 'scale': 13388968.830054749}}
# spring-projects_spring-boot
# {'cauchy': {'loc': 1531399343.1665769, 'scale': 44914764.28031714}}
# MycroftAI_mycroft-core
# {'cauchy': {'loc': 1519599871.5637546, 'scale': 402899.4043829852}}
# makersacademy_airport_challenge
# {'powerlaw': {'a': 1.1109977911987097, 'loc': 1416559817.1870732, 'scale': 198854364.8129273}}
# majesty86_phase-0-tracks
# {'gamma': {'a': 21.830758743009707, 'loc': 1418107468.8487701, 'scale': 2813360.288144259}}
# licshire_public-buildpacks-ci-robots
# {'norm': {'loc': 1543833851.8211966, 'scale': 30719284.08289429}}
# Tiseg_github-slideshow
# {'powerlaw': {'a': 2.479785634762961, 'loc': 1513126528.5194812, 'scale': 102533688.55703798}}
# jkim664_junik
# {'expon': {'loc': 0.0, 'scale': 5667318.280136387}}
# apache_hbase
# {'rayleigh': {'loc': 1193840949.3793378, 'scale': 180174094.5705547}}
# pawohl_studip
# {'cauchy': {'loc': 1325541536.6277442, 'scale': 103174390.52439076}}
# gitorious.org_wxfork/wxwidgets
# {'norm': {'loc': 1122334523.687479, 'scale': 96764674.48868568}}
# star-bnl_star-sw
# {'rayleigh': {'loc': 795954061.6939901, 'scale': 287421626.938725}}
# jthub_ega-file-transfer-to-collab-3-jtracker
# {'cauchy': {'loc': 1500241901.2771704, 'scale': 788954.1168739162}}
# evileval_wooyun-image-2015
# {'expon': {'loc': 1544754759.0, 'scale': 251420.61484241486}}
# haiku_haiku
# {'rayleigh': {'loc': 989445134.8548884, 'scale': 200507615.13499922}}
# gitlab.com_quicla_kernel/lk
# {'norm': {'loc': 1474809349.1677542, 'scale': 90978175.51710206}}
# sujaypat_cs225
# {'expon': {'loc': 0.0, 'scale': 5543682.958006299}}
# ahf_tor-jenkins
# {'powerlaw': {'a': 1.3137193173562678, 'loc': 1356872089.3660727, 'scale': 57879763.63392743}}
# tmtmtmtm_mexico-diputados-2015
# {'rayleigh': {'loc': 1470963850.1035624, 'scale': 27067153.77899928}}
# commit-b0t_commit-b0t
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED powerlaw distribution (taking more than 120 seconds)
# {'uniform': {'loc': 1604774628.0, 'scale': 7595949.0}}
# cirosantilli_test-many-commits-1m
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# {'gamma': {'a': 0.1552564569945486, 'loc': -2.0794895717881375e-19, 'scale': 183806181.68569684}}
# ngriffin7a_icefaces4-trunk
# {'cauchy': {'loc': 1371088058.9918246, 'scale': 64151949.39982158}}
# rust-lang_rust
# {'powerlaw': {'a': 1.56442572385534, 'loc': 1272711362.1358778, 'scale': 342682403.8641228}}
# SockPuppetry_Loop-A
# {'powerlaw': {'a': 0.7793811257685694, 'loc': 1523706441.9999995, 'scale': 90476741.27844492}}
# gspu_vbox
# {'norm': {'loc': 1352067727.8830824, 'scale': 120653648.61919682}}
# rathena_rathena
# {'powerlaw': {'a': 0.9441901170847613, 'loc': 1099610343.9999998, 'scale': 515364642.64000124}}
# jasoncalabrese_indy2d
# {'uniform': {'loc': 1464841249.0, 'scale': 23686389.0}}
# raytapan_mgm-ice-R22
# {'gamma': {'a': 0.5748856812737186, 'loc': -2.1334319786196365e-17, 'scale': 290990946.9886663}}
# rubygems_rubygems
# {'powerlaw': {'a': 2.0004743620523624, 'loc': 884949054.3207679, 'scale': 730355359.6792333}}
# openbsd-unofficial_openbsd-src
# {'powerlaw': {'a': 1.126674739445479, 'loc': 813975889.0856125, 'scale': 646571835.9171755}}
# gitlab.com_szzdlab_djy
# {'gamma': {'a': 1.5472622798215059, 'loc': 1569372660.292513, 'scale': 957721.3255463564}}
# ocaml_opam-bulk-logs
# {'cauchy': {'loc': 1409585160.966435, 'scale': 1687678.772032146}}
# racket_racket
# {'norm': {'loc': 1256904672.707254, 'scale': 170346822.97676778}}
# jh3y_pic
# {'powerlaw': {'a': 0.5199086466137004, 'loc': 1406890799.9999998, 'scale': 202926327.82623616}}
# hashibiroko_tanoshi
# {'uniform': {'loc': 1507099146.0, 'scale': 63496255.0}}
# brianchandotcom_liferay-portal
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# {'norm': {'loc': 1472471403.1471527, 'scale': 78511443.73944888}}
# greedyboy_blogBak
# {'cauchy': {'loc': 1574652416.4123847, 'scale': 1875759.826028763}}
# mikemcqueen_WordGameClues
# {'norm': {'loc': 1497011241.1165934, 'scale': 5636613.891732084}}
# suzutan0s2_contribution-calender
# {'cauchy': {'loc': 1479083658.2935941, 'scale': 2208265.707086811}}
# Alsan_turing-chunk07
# {'powerlaw': {'a': 1.57426441531224, 'loc': 1163261575.511809, 'scale': 232544422.4881909}}
# godotengine_godot
# {'powerlaw': {'a': 4.821325875524538, 'loc': 1083261701.6013145, 'scale': 532411423.39868546}}
# tmtmtmtm_philippines-house-of-representatives
# {'powerlaw': {'a': 2.6617837370861848, 'loc': 1436089637.6242766, 'scale': 102048163.60071927}}
# gitlab.com_quicla_platform/packages/apps/Settings
# {'gamma': {'a': 327931.0879940743, 'loc': -44685080688.62368, 'scale': 140719.07281805566}}
# mozillazg_pypy
# {'norm': {'loc': 1326686869.443913, 'scale': 117552788.9844233}}
# LibreELEC_LibreELEC.tv
# {'cauchy': {'loc': 1486069683.028747, 'scale': 41742753.4061189}}
# liu76874151_appsuite-middleware
# {'norm': {'loc': 1378318515.9236422, 'scale': 119074991.1704161}}
# g0v-data_mirror-minutely
# {'powerlaw': {'a': 0.8181880368660299, 'loc': 1514470695.9999998, 'scale': 68776135.18819204}}
# firemodels_fds
# {'norm': {'loc': 1376282438.5614777, 'scale': 98645747.38741723}}
# TheMattSykes_personal-website
# {'powerlaw': {'a': 34.2165937045267, 'loc': -2161937879.723963, 'scale': 3777852526.60071}}
# OSGeo_grass-legacy
# {'powerlaw': {'a': 1.0351905465665097, 'loc': 946477469.814145, 'scale': 604529460.1858561}}
# PrestaShop_PrestaShop
# {'powerlaw': {'a': 1.6091463214617114, 'loc': 1227765996.819982, 'scale': 387270068.1800184}}
# gitlab.com_quicla_platform/system/netd
# {'powerlaw': {'a': 3.2650730375637593, 'loc': 1165963167.1380854, 'scale': 449363216.8630543}}
# aws-aemilia_CanaryTestOnly-DoNotTouch-ap-east-1
# {'norm': {'loc': 1552583258.5597296, 'scale': 8138700.396129614}}
# wmshort_latinwordnet-archive
# {'rayleigh': {'loc': 1570848747.8167102, 'scale': 14220397.74155846}}
# devkitPro_newlib
# {'cauchy': {'loc': 1498617503.8003387, 'scale': 82670833.99347925}}
# EricLindemann_CSCI-4308-Open-Sources-Data-Analytics
# {'rayleigh': {'loc': 1446994424.596965, 'scale': 5796194.602139753}}
# edom_eclipse
# {'powerlaw': {'a': 18.625471366620804, 'loc': -1232002655.6398082, 'scale': 2847725607.639808}}
# NgoMike_gitfiti
# {'norm': {'loc': 1539509055.3428645, 'scale': 1669656.5116491916}}
# cirosantilli_imagine-all-the-people
# WARNING:root:SKIPPED gamma distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED rayleigh distribution (taking more than 120 seconds)
# {'lognorm': {'s': 10.034478507384776, 'loc': 946684799.9999998, 'scale': 32.073442406187915}}
# qooxdoo_qooxdoo
# {'cauchy': {'loc': 1218599973.638617, 'scale': 40561201.86994439}}
# pcheng11_RainGame
# {'expon': {'loc': 0.0, 'scale': 3501404.409933381}}
# openssl_openssl
# {'cauchy': {'loc': 1478826037.8329525, 'scale': 76364812.8928819}}
# ofiwg_libfabric
# {'rayleigh': {'loc': 1332220597.1983085, 'scale': 133472157.43726727}}
# szeder_all-git-forks
# {'gamma': {'a': 296.7829954601772, 'loc': -938133306.9308827, 'scale': 7813762.661874846}}
# hannesmuehleisen_MonetDBLite-C
# {'rayleigh': {'loc': 1041528310.3758285, 'scale': 199849216.86230925}}
# jadonk_bonescript
# {'rayleigh': {'loc': 1426013695.084292, 'scale': 81809064.5131438}}
# roytam1_mozilla-cvs-history-subtree
# {'gamma': {'a': 1.7771304581584475, 'loc': 888067037.1158898, 'scale': 91636966.67984787}}
# wikimedia_integration-config
# {'rayleigh': {'loc': 1402638187.2902806, 'scale': 70246903.3060824}}
# AlfrescoTestAutomation_alfresco-desktopsync
# {'powerlaw': {'a': 154.0473890316795, 'loc': -11946720837.220512, 'scale': 13374469612.136166}}
# mkschreder_openwrt-xorg-feed
# {'rayleigh': {'loc': 1225800859.8651989, 'scale': 43466427.81105269}}
# openstack_openstack
# {'gamma': {'a': 3.252092231477349, 'loc': 1365235570.4822068, 'scale': 38738677.42653029}}
# sourcemage_grimoire
# {'expon': {'loc': 1132918201.0, 'scale': 198948658.84935665}}
# Wadauk_scihub_ck
# {'cauchy': {'loc': 1523602262.3290415, 'scale': 1983642.6103523592}}
# pbaffiliatetwoop_testRepository
# {'powerlaw': {'a': 1.1037270484809465, 'loc': 1500036401.642048, 'scale': 50165184.43717188}}
# repo.or.cz_tails
# {'rayleigh': {'loc': 1243140826.7104926, 'scale': 149380435.58632776}}
# mtn_cocoa-eh-hugo-theme
# {'cauchy': {'loc': 1577535317.5117629, 'scale': 11573074.862638783}}
# bio-repo_ncbi_cpp_toolkit
# {'gamma': {'a': 3312.310106841267, 'loc': -7421476975.743675, 'scale': 2611090.5260117147}}
# topcoder-platform_tc-online-review
# {'gamma': {'a': 0.3416224538199115, 'loc': -1.4390223681724228e-13, 'scale': 304613272.9339231}}
# ballerina-platform_ballerina-lang
# {'gamma': {'a': 46.99347872363829, 'loc': 1264121479.6495385, 'scale': 5794538.704850736}}
# mad-science_18135
# {'uniform': {'loc': 1461700851.0, 'scale': 731.0}}
# Plailect_Guide_3DS
# {'cauchy': {'loc': 1497621490.8824766, 'scale': 9775538.17312051}}
# google_angle
# {'powerlaw': {'a': 3.0497352100526687, 'loc': 1236162037.1042213, 'scale': 379449290.91157806}}
# pars-linux_corporate2
# {'cauchy': {'loc': 1273912858.2856414, 'scale': 25058527.19334188}}
# rossabaker_abolish-ice
# {'powerlaw': {'a': 0.8902926736567531, 'loc': 1561910400.9999962, 'scale': 32056945.095367663}}
# xbmc_xbmc
# {'rayleigh': {'loc': 1048180537.6306038, 'scale': 205163145.71651965}}
# sourceconnect-testing_reposync
# {'powerlaw': {'a': 1.117540252298201, 'loc': 1522787146.5747833, 'scale': 59772380.42521684}}
# ChristopheDucamp_christopheducamp.github.io
# {'norm': {'loc': 1533384260.8488379, 'scale': 6786562.124561885}}
# trilinos_Trilinos
# {'norm': {'loc': 1305107942.2758992, 'scale': 156599692.06570336}}
# BOINC_boinc
# {'gamma': {'a': 3.7029105035851506, 'loc': 984319038.8032234, 'scale': 67974899.28801346}}
# tmtmtmtm_romanian-parliament
# {'rayleigh': {'loc': 1465210185.1366487, 'scale': 41788453.5187714}}
# MariusCiocanel_0.0
# {'powerlaw': {'a': 2.169739962168004, 'loc': 1350012371.4154782, 'scale': 264506208.58452213}}
# demisto_content
# {'powerlaw': {'a': 2.384741901946528, 'loc': 1465125003.1537645, 'scale': 150200788.8466062}}
# qemu_edk2
# {'powerlaw': {'a': 1.290798484135443, 'loc': 1142604908.6256433, 'scale': 472414208.37435865}}
# regro_repodata-shards
# {'gamma': {'a': 1.5392406336726387, 'loc': 1597229823.4838543, 'scale': 4589789.245705906}}
# xanderself_one-million-commit
# WARNING:root:SKIPPED rayleigh distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED gamma distribution (taking more than 120 seconds)
# {'lognorm': {'s': 10.03446774061465, 'loc': 946681199.9999999, 'scale': 32.07334974829573}}
# infaautovcs_DependencyUIAuto
# {'cauchy': {'loc': 1604647438.6526601, 'scale': 2045184.1521463303}}
# mquinson_PLM-data
# {'rayleigh': {'loc': 1389010097.4816294, 'scale': 45060531.03270767}}
# obfuscated_codeblocks_sf
# {'gamma': {'a': 2.141479973614353, 'loc': 1080967176.3509812, 'scale': 91816738.28075254}}
# istio_istio
# {'powerlaw': {'a': 1.3005304927610712, 'loc': 1479512058.7634654, 'scale': 136171150.23653495}}
# xwvvvvwx_untrustix-git-testdata
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# {'uniform': {'loc': 0.0, 'scale': 3325786.0}}
# Indicia-Team_drupal-7-module-jquerymobile
# {'cauchy': {'loc': 1382376036.243361, 'scale': 29757267.44606878}}
# SSWConsulting_SSW.Rules
# {'powerlaw': {'a': 1.3658886717069654, 'loc': 1237402167.6495352, 'scale': 377172775.3504649}}
# mozilla_gecko-dev
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED gamma distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED chi2 distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED powerlaw distribution (taking more than 120 seconds)
# {'cauchy': {'loc': 1384301896.1183896, 'scale': 116687259.3302983}}
# android.googlesource.com_platform_external/qemu
# {'cauchy': {'loc': 1501030634.4208078, 'scale': 58629777.95485687}}
# RIOT-OS_RIOT
# {'norm': {'loc': 1506778432.4667795, 'scale': 58076279.90614624}}
# oqeerbfo_OEIS-copy
# WARNING:root:SKIPPED rayleigh distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED gamma distribution (taking more than 120 seconds)
# {'lognorm': {'s': 12.06931647980091, 'loc': 1223114239.9999998, 'scale': 26.67804526833227}}
# skbkontur_hackathon-2018.1-team6
# {'norm': {'loc': 1523130540.3930054, 'scale': 59362.243516233815}}
# petervandivier_link-breaker
# {'rayleigh': {'loc': 1597405749.555376, 'scale': 4425.351742890041}}
# skbkontur_hackathon-2018.1-team20
# {'norm': {'loc': 1523135732.7067919, 'scale': 1594.0436474296378}}
# asterisk_asterisk
# {'gamma': {'a': 28.162389041910885, 'loc': 701405087.1689712, 'scale': 20447843.946263745}}
# CRAZYFAKE_handiwork
# {'norm': {'loc': 1492995647.0484793, 'scale': 1929468.3139777859}}
# wikimedia_mediawiki-extensions-MobileFrontend
# {'gamma': {'a': 3.8835068954533023, 'loc': 1305496587.4503565, 'scale': 32916138.751691356}}
# Azure_azure-sdk-for-python
# {'norm': {'loc': 1565909630.308889, 'scale': 36057722.90504677}}
# feralEndre_sensorinfo
# {'powerlaw': {'a': 1.0153738555700675, 'loc': 1582474355.4895458, 'scale': 32854412.70089525}}
# MmxBoy_ELT-BOT
# {'cauchy': {'loc': 1460835881.3716505, 'scale': 5802240.218367286}}
# WPArena_SEO-WP
# {'cauchy': {'loc': 1425402426.5239885, 'scale': 48279024.9760544}}
# Leaflet_Leaflet
# {'norm': {'loc': 1459931343.1051598, 'scale': 89063738.50849374}}
# weiyeh_OpenBSD-src
# {'powerlaw': {'a': 1.11508831005284, 'loc': 813983569.0552816, 'scale': 576681051.9447203}}
# AdrianDC_aosp_development_sony8960_q
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# {'norm': {'loc': 1476539314.3913994, 'scale': 90811623.72002663}}
# easybuilders_easybuild-easyconfigs
# {'powerlaw': {'a': 1.3469215877982137, 'loc': 1331189830.8877473, 'scale': 284276843.1122527}}
# va1entei_retdec
# {'uniform': {'loc': 1584349960.0, 'scale': 7203105.0}}
# f-droid_fdroiddata
# {'powerlaw': {'a': 2.225988375269422, 'loc': 1278603168.7946172, 'scale': 336708758.2053828}}
# samber_powEUr
# {'powerlaw': {'a': 0.9861679197706716, 'loc': 1547912293.9999995, 'scale': 67009935.944200136}}
# nicopeters_sigrhtest
# {'norm': {'loc': 1518622988.7009363, 'scale': 16670277.182326734}}
# kuali_kc
# {'rayleigh': {'loc': 1166269630.5402195, 'scale': 126186147.4974281}}
# jthub_ega-file-transfer-to-collab-1-jtracker
# {'norm': {'loc': 1497344971.6322536, 'scale': 981498.51765203}}
# JacksonChen666_h
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# {'cauchy': {'loc': 1604886877.5448308, 'scale': 6868.830878627451}}
# php_php-src
# {'gamma': {'a': 2.8522601712943736, 'loc': 887561549.7793348, 'scale': 119121676.88315919}}
# racarr01_racarr01.github.io
# {'powerlaw': {'a': 0.8976553969513237, 'loc': 1534180478.9999995, 'scale': 50998247.52421282}}
# supershell2019_conf
# {'powerlaw': {'a': 1.2517162664691002, 'loc': 1566753774.0136442, 'scale': 43877238.98635632}}
# NRYAN15_241
# {'expon': {'loc': 0.0, 'scale': 9277395.859820532}}
# one-million-repo_biggest-repo-ever
# WARNING:root:SKIPPED cauchy distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED powerlaw distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED gamma distribution (taking more than 120 seconds)
# {'uniform': {'loc': 1548597145.0, 'scale': 446183.0}}
# user135711_jdownloaderClient
# {'norm': {'loc': 1390396808.1115918, 'scale': 77191310.96863772}}
# nhirata_gecko-dev
# {'cauchy': {'loc': 1373517310.6045496, 'scale': 63556103.85184693}}
# archlinuxcn_repo
# {'powerlaw': {'a': 2.7183217938154747, 'loc': 1362491061.8666892, 'scale': 251827505.13331097}}
# Arshiamidos_84ck1N617
# {'cauchy': {'loc': 1553493183.5431256, 'scale': 6705294.22094695}}
# eea_Products.EEAContentTypes
# {'cauchy': {'loc': 1330808560.2733026, 'scale': 32883816.166495703}}
# pytorch_pytorch
# {'norm': {'loc': 1552401277.1156552, 'scale': 44346243.18173786}}
# oroinc_platform
# {'rayleigh': {'loc': 1351023511.9578195, 'scale': 86528842.48279971}}
# arangodb_arangodb
# {'powerlaw': {'a': 1.2620118563473377, 'loc': 1319608238.847269, 'scale': 295370950.15273094}}
# lvotypko_javatest-report
# {'norm': {'loc': 1248348345.2702296, 'scale': 37754733.211061046}}
# macvim-dev_macvim
# {'norm': {'loc': 1387379812.3968964, 'scale': 133595159.16663307}}
# CartoDB_cartodb
# {'norm': {'loc': 1437087317.2556434, 'scale': 64427755.545859575}}
# luminousbeam_gitfiti-fun
# {'cauchy': {'loc': 1543846177.3076248, 'scale': 1699655.8841597836}}
# yiisoft_yii2
# {'rayleigh': {'loc': 1298359929.726206, 'scale': 110454602.53362384}}
# tmtmtmtm_pakistan-national-assembly
# {'gamma': {'a': 508.8800931857743, 'loc': 940484514.1062143, 'scale': 1136859.4257575702}}
# AurevoirXavier_HGC
# {'chi2': {'df': 1.0082867723078204, 'loc': 1574655389.9999995, 'scale': 610909.953447652}}
# kyle-barker_London
# {'powerlaw': {'a': 1.060888903068517, 'loc': 1490953306.7229452, 'scale': 97204693.27705497}}
# dotnet_corefx
# {'rayleigh': {'loc': 1394422357.6379137, 'scale': 97262121.96718563}}
# bpeabody_mongo
# {'powerlaw': {'a': 0.6875371242408875, 'loc': 1483582178.9999995, 'scale': 28985.31713616421}}
# danrue_oh_my_fortune
# {'powerlaw': {'a': 1.005208086128435, 'loc': -112210.8389958743, 'scale': 3155794562.8390684}}
# OpenDataSpace_jlan
# {'gamma': {'a': 0.21260330679936368, 'loc': -5.47122270480357e-21, 'scale': 294339704.6914114}}
# gitlab.com_quicla_platform/packages/apps/Contacts
# {'norm': {'loc': 1466225827.6824286, 'scale': 80603666.6079423}}
# trattkantarell_src
# {'norm': {'loc': 1082278837.0669987, 'scale': 135865115.94833028}}
# usehotkey_counter
# {'exponpow': {'b': 0.9938662711265883, 'loc': 1510989861.9999995, 'scale': 191870.35070776104}}
# 5d2_images
# {'cauchy': {'loc': 1598820191.4048734, 'scale': 610392.5446423126}}
# nanoframework_ChibiOS-bkp
# {'powerlaw': {'a': 181496226.5793242, 'loc': -3428669758098192.0, 'scale': 3428671345041461.0}}
# Ratcanal_Rafa
# {'norm': {'loc': 1294603243.9603124, 'scale': 73993483.64840819}}
# bewest_openaps-example
# {'cauchy': {'loc': 1465000209.6926541, 'scale': 2281911.1770386817}}
# fuglede_github-contributions-filler
# {'cauchy': {'loc': 1459608843.2079704, 'scale': 363.7622377247771}}
# myatt83_kuali-student
# {'cauchy': {'loc': 1369051609.1380692, 'scale': 22222558.47551497}}
# carolmanderson_academic-kickstart
# {'norm': {'loc': 1566646899.9357271, 'scale': 32192402.324631557}}
# jerry-jx_tikiwiki
# {'cauchy': {'loc': 1289417551.567881, 'scale': 45847884.85070962}}
# whfern_watchthis
# {'exponpow': {'b': 0.36595700624790184, 'loc': 1412184802.9999998, 'scale': 8522913.029919136}}
# ghthor_insync
# {'powerlaw': {'a': 0.9233049463350829, 'loc': 1528766148.9911356, 'scale': 9247986.508019082}}
# gitlab.freedesktop.org_xorg_xserver
# {'gamma': {'a': 514.4739018290938, 'loc': -1869949881.6737623, 'scale': 6199208.931112256}}
# cms-sw_cmssw
# {'rayleigh': {'loc': 1118389923.086702, 'scale': 174252015.7362931}}
# gem_oq-engine
# {'powerlaw': {'a': 1.2266442134019404, 'loc': 1279431589.338829, 'scale': 335330860.6611711}}
# apache_tomcat
# {'powerlaw': {'a': 1.7140282097598267, 'loc': 964013269.1237898, 'scale': 650624363.8762119}}
# duaneking_metrics
# {'norm': {'loc': 3385969591.5363235, 'scale': 92763448.4896411}}
# stevezg_weirdflexbutok
# {'gamma': {'a': 4.7962179364772055, 'loc': 748291003.0367447, 'scale': 92908721.4242158}}
# openresty_lua-nginx-module
# {'cauchy': {'loc': 1448751866.9169095, 'scale': 16058513.311142497}}
# citp_privacy-policy-historical
# {'norm': {'loc': 1377713490.1912868, 'scale': 133211987.83412068}}
# anappwilos_AutoCommit
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# {'powerlaw': {'a': 0.45414728516068914, 'loc': 1524220559.9999998, 'scale': 54980753.01935017}}
# everypolitician-scrapers_belarus-house-of-representatives-2016
# {'powerlaw': {'a': 1.4422725778318837, 'loc': 1476108436.8472338, 'scale': 61410737.45546967}}
# WebKit_webkit
# {'cauchy': {'loc': 1323904640.4436266, 'scale': 65174387.49157475}}
# gitlab.com_anonimal_monero
# {'cauchy': {'loc': 1524707813.7349892, 'scale': 30504230.47080244}}
# MoKee_android_packages_apps_Gallery2
# {'gamma': {'a': 68.57508193606708, 'loc': 731465485.9158583, 'scale': 10343905.411604993}}
# hookzof_socks5_list
# {'norm': {'loc': 1605535803.6398587, 'scale': 6513791.91235829}}
# gentoo_sci
# {'cauchy': {'loc': 1351059973.6832585, 'scale': 20373321.85352315}}
# django_django
# {'rayleigh': {'loc': 1094792377.1152663, 'scale': 194047749.86160865}}
# highfidelity_hifi
# {'gamma': {'a': 335.67150113324044, 'loc': 363455066.1368917, 'scale': 3305527.8504832033}}
# eclipse_birt
# {'cauchy': {'loc': 1524760582.0722873, 'scale': 87082.0585361056}}
# szzd3_fq
# {'rayleigh': {'loc': 1531019245.390325, 'scale': 10635713.704331791}}
# MaybeNotWrong_lc-sep
# {'cauchy': {'loc': 1557215004.462021, 'scale': 6753076.652598226}}
# sbmlteam_sbml-test-suite
# {'norm': {'loc': 1291895829.1750798, 'scale': 110390131.21254425}}
# freenas_freenas
# {'norm': {'loc': 1410090973.254121, 'scale': 115342841.29731202}}
# avsm_ocaml-ci.logs
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# {'powerlaw': {'a': 1.1562359018133241, 'loc': 1480850698.7899952, 'scale': 1699381.2100048647}}
# DOCGroup_ACE_TAO
# {'norm': {'loc': 1079161275.1464956, 'scale': 154951475.99776322}}
# alexandruchirita4192_MqlPersonal
# {'expon': {'loc': 0.0, 'scale': 7339387.3490984505}}
# learn-co-students_array-CRUD-lab-v-000
# {'norm': {'loc': 1538295562.288411, 'scale': 28673244.101565585}}
# breakingheatmap_breakingheatmap
# {'powerlaw': {'a': 1.0681209574253243, 'loc': 1594970759.5199847, 'scale': 19595912.659784973}}
# urho3d_Urho3D
# {'norm': {'loc': 1391813206.708436, 'scale': 128477768.92453414}}
# miatribe_pipvpspy
# {'powerlaw': {'a': 0.8035395439838167, 'loc': 1435020130.9999998, 'scale': 66368802.47221796}}
# gitlab.com_jedbrown_petsc
# {'powerlaw': {'a': 1.843596218607245, 'loc': 758877615.0927639, 'scale': 856770606.9072375}}
# opencog_opencog
# {'norm': {'loc': 1404395655.1544454, 'scale': 98088143.8233353}}
# 0xbzho_keybase
# {'cauchy': {'loc': 1463952063.8411045, 'scale': 2127892.480957224}}
# JetBrains_kotlin
# {'cauchy': {'loc': 1507128379.4038804, 'scale': 35851812.116923094}}
# django-oscar_django-oscar
# {'rayleigh': {'loc': 1242787923.4269464, 'scale': 83690037.07885115}}
# pombredanne_sf.net-brlcad
# {'cauchy': {'loc': 1297179119.291506, 'scale': 130372853.99660057}}
# joyent_pkgsrc-wip
# {'powerlaw': {'a': 0.8317622728478569, 'loc': 1048023271.9999971, 'scale': 567366068.7904623}}
# it-projects-llc_addons-dev
# {'powerlaw': {'a': 3.89688294119583, 'loc': 1186237415.3059902, 'scale': 429339118.6968786}}
# open-mpi_ompi
# {'exponpow': {'b': 1.0429542370704947, 'loc': 1069518084.1479499, 'scale': 352320787.2043361}}
# Ne00n_Hetzner
# {'powerlaw': {'a': 0.9898470855147655, 'loc': 1551644194.9999995, 'scale': 27475306.102961212}}
# Mastermaulik_ofbiz
# {'cauchy': {'loc': 1269732542.9372547, 'scale': 71383218.19245073}}
# marco-c_gecko-dev-wordified
# {'lognorm': {'s': 1.7274498944874919, 'loc': 1577835251.0698712, 'scale': 217804.5631337525}}
# casey_boot
# {'cauchy': {'loc': 1528423107.3642707, 'scale': 547787.8249436226}}
# dotnet_aspnetcore
# {'norm': {'loc': 1477818427.1988602, 'scale': 104754675.83234039}}
# mpv-player_mpv
# {'rayleigh': {'loc': 948006344.5749778, 'scale': 225742323.65443286}}
# ConstipatedNinja_IPMI-Temperature-Monitoring
# {'gamma': {'a': 345.1924607667519, 'loc': 1387566535.6441069, 'scale': 355963.33612048405}}
# scummvm_scummvm
# {'gamma': {'a': 238012.3428527324, 'loc': -72655776411.49878, 'scale': 310941.8923735173}}
# jasoncalabrese_indy-e4b
# {'powerlaw': {'a': 0.9753572445095444, 'loc': 1465380305.4226713, 'scale': 22820261.75424552}}
# AlejandroHCruz_dailypush
# {'cauchy': {'loc': 1465918411.0615776, 'scale': 2527296.040875369}}
# shubhamagarwal1993_Data-Structures
# {'expon': {'loc': 0.0, 'scale': 5981135.602890301}}
# spip_SPIP
# {'norm': {'loc': 1310920706.955201, 'scale': 139544215.2912423}}
# HYDPublic_relint-ci-pools
# {'powerlaw': {'a': 1.8697262231611935, 'loc': 1487113102.7575245, 'scale': 127953779.28427511}}
# videojs_videojs-contrib-hls
# {'powerlaw': {'a': 3.834752180475835, 'loc': 978392828.3356049, 'scale': 637042484.6643951}}
# wildfly_wildfly
# {'gamma': {'a': 8.21230855132507, 'loc': 1146115563.1020145, 'scale': 31985647.38381408}}
# rust-lang_crates.io-index
# {'powerlaw': {'a': 1.925316374497882, 'loc': 1413734577.3060412, 'scale': 200229399.69395882}}
# savoirfairelinux_ring-daemon
# {'cauchy': {'loc': 1599107207.68326, 'scale': 16756225.19865054}}
# bitbucket.org_akhudavets_qa-165k-jira-keys
# {'rayleigh': {'loc': 1338346645.6749732, 'scale': 5021.117557890783}}
# robertbrook_robertbrook.github.io
# {'cauchy': {'loc': 1510117023.1351347, 'scale': 4281118.047289882}}
# I2PC_scipion
# {'norm': {'loc': 1374982538.3830428, 'scale': 98979873.30983676}}
# wellcomez_MacPorts
# {'powerlaw': {'a': 1.9063548547597011, 'loc': 1011883178.5261046, 'scale': 465983909.473897}}
# samuraitruong_cm-spin
# {'powerlaw': {'a': 1.4776730594931435, 'loc': 1571309842.562469, 'scale': 44025888.437531084}}
# marcelstoer_nodemcu-custom-build
# {'gamma': {'a': 4.813559747224038, 'loc': 1414767449.310378, 'scale': 21365986.733796567}}
# webmproject_libvpx
# {'gamma': {'a': 35.380393815757635, 'loc': 1057331863.5904534, 'scale': 10981948.530412342}}
# bitbucket.org_seanfarley_macports-git
# {'powerlaw': {'a': 1.50638834143609, 'loc': 1025009766.1182904, 'scale': 430814757.8817096}}
# docker-library_commit-warehouse
# {'cauchy': {'loc': 1450203931.772253, 'scale': 53967631.63884191}}
# prestodb_presto
# {'norm': {'loc': 1499925752.3636756, 'scale': 65355217.24510918}}
# NetBSD_src
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED gamma distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED powerlaw distribution (taking more than 120 seconds)
# {'norm': {'loc': 1119035664.016087, 'scale': 186656048.32183617}}
# jonike_dava.engine
# {'norm': {'loc': 1426893195.4271405, 'scale': 47351108.79916834}}
# MIPS_gcc
# {'norm': {'loc': 1230192319.2548964, 'scale': 216484899.56669417}}
# FusionPlmH_dead-block
# {'powerlaw': {'a': 1.0320572174197935, 'loc': 1598784606.131919, 'scale': 15419176.868081275}}
# cockroachdb_cockroach
# {'powerlaw': {'a': 1.7996474398529294, 'loc': 1391475960.9465365, 'scale': 223768343.05346352}}
# wking_swc-boot-camps-v2
# {'norm': {'loc': 1496090494.9723544, 'scale': 70705814.13232288}}
# opendaylight_yangtools
# {'powerlaw': {'a': 1.1652942165212314, 'loc': 1374186105.821247, 'scale': 241131668.17875314}}
# BVLC_caffe
# {'gamma': {'a': 137.39582044129105, 'loc': 906044806.055479, 'scale': 4060046.781026899}}
# LambdaSchool_JavaScript-I
# {'norm': {'loc': 1550374804.9241285, 'scale': 17472236.132545862}}
# IIJ-NetBSD_netbsd-src
# {'powerlaw': {'a': 1.0414647670461497, 'loc': 711044163.0612166, 'scale': 904480898.938785}}
# jasoncalabrese_indy-e4
# {'powerlaw': {'a': 1.403214028343807, 'loc': 1457776682.98768, 'scale': 7604843.054677937}}
# Pardus-Linux_yali
# {'norm': {'loc': 1219203899.1642752, 'scale': 61912219.84385047}}
# Luke0915_Unreal422
# {'powerlaw': {'a': 0.9780129793911965, 'loc': 1394820820.9999998, 'scale': 210840812.68539935}}
# dotnet_cli
# {'cauchy': {'loc': 1562834598.8495383, 'scale': 22671557.89292626}}
# hasura_imad-app
# {'cauchy': {'loc': 1503070530.966352, 'scale': 2138741.7959049633}}
# vinnymac_vinnymac.github.io
# {'rayleigh': {'loc': 1530600155.5811386, 'scale': 37929434.12412133}}
# ceph_ceph
# {'norm': {'loc': 1476731233.1033752, 'scale': 88409280.81960472}}
# Automattic_wp-calypso
# {'rayleigh': {'loc': 1436260716.2315876, 'scale': 69781349.91827829}}
# schlos_croatia-parliament-archive
# {'gamma': {'a': 10.418544171353638, 'loc': 1441598471.0259027, 'scale': 6452244.864430929}}
# l_debian-webwml
# {'gamma': {'a': 2.8859707524816045, 'loc': 884228070.3822827, 'scale': 97985438.47908561}}
# wikimedia_puppet
# {'norm': {'loc': 1459080252.6448536, 'scale': 64687734.181885645}}
# mono_mono
# {'powerlaw': {'a': 5.577806292641007, 'loc': -14012704.879429437, 'scale': 1629624565.4074354}}
# AnnaLut_abs3
# {'powerlaw': {'a': 34.28554906732194, 'loc': -1121085.3417655013, 'scale': 1561054038.0048256}}
# jshint_jshint
# {'cauchy': {'loc': 1492589736.9217415, 'scale': 936303.217604769}}
# sobotka_blender
# {'cauchy': {'loc': 1290219599.1720557, 'scale': 45853348.85498077}}
# wertklop_intellij-community
# {'powerlaw': {'a': 1.5881967557710182, 'loc': 1099660877.0099669, 'scale': 516012192.1480322}}
# piyawad_test1
# {'cauchy': {'loc': 1249203777.8106518, 'scale': 54603958.18480198}}
# redhat-openstack_khaleesi
# {'norm': {'loc': 1435571924.686916, 'scale': 18563939.544687707}}
# benhager_benhager.github.io
# {'norm': {'loc': 1510460831.219641, 'scale': 7229705.862803258}}
# guardian_frontend
# {'gamma': {'a': 3.301641558326425, 'loc': 1324476727.6057582, 'scale': 37527650.332235634}}
# crowbar_ci-tracking
# {'cauchy': {'loc': 1371865213.97256, 'scale': 4057728.203227501}}
# rastaman_argouml-maven
# {'norm': {'loc': 1143524496.2648199, 'scale': 90975248.305607}}
# reactos_reactos
# {'gamma': {'a': 8.517748888079453, 'loc': 751118271.875825, 'scale': 61797730.56284097}}
# rabbitmq_rabbitmq-server
# {'powerlaw': {'a': 2.0576787729246258, 'loc': 1085827262.2419426, 'scale': 529761153.7580576}}
# octopusinvitro_gitbanner
# {'uniform': {'loc': 1393778106.0, 'scale': 603763200.0}}
# nturaga_bioc_manifest
# {'cauchy': {'loc': 1379379267.2427268, 'scale': 91318551.22542831}}
# opentimestamps_nist-inject
# {'uniform': {'loc': 1546853875.0, 'scale': 67543333.0}}
# s7ephen_PrivacyChanges_Public
# {'rayleigh': {'loc': 1441071965.6256468, 'scale': 469998.1451377831}}
# gitlab.com_quicla_device/google/cuttlefish
# {'powerlaw': {'a': 2.1741091450421797, 'loc': 1494440283.2413645, 'scale': 118974334.54065935}}
# cakephp_cakephp
# {'cauchy': {'loc': 1335683317.7539723, 'scale': 62420490.4592887}}
# tumblenet_TumbleSMP
# {'powerlaw': {'a': 1.4181237357669927, 'loc': 1531752657.6185875, 'scale': 8416598.386072267}}
# dockercore_data
# {'uniform': {'loc': 1608804863.0, 'scale': 894552.0}}
# keum_cso_digitalocean
# {'uniform': {'loc': 1459452373.0, 'scale': 121671828.0}}
# wikimedia_mediawiki-extensions-Flow
# {'gamma': {'a': 1.9352674950263489, 'loc': 1372676103.540197, 'scale': 32346487.928060144}}
# jthub_ega-file-transfer-to-collab-2-jtracker
# {'exponpow': {'b': 0.9524536745505536, 'loc': 1498834407.9999995, 'scale': 2582397.7624434493}}
# babburra_CS-125
# {'expon': {'loc': 0.0, 'scale': 2718741.3920531925}}
# wikimedia_mediawiki
# {'norm': {'loc': 1372916331.5111072, 'scale': 134629925.3125113}}
# glpi-project_glpi
# {'cauchy': {'loc': 1310636066.7620084, 'scale': 78182395.7848507}}
# bitcoin_bitcoin
# {'cauchy': {'loc': 1523844803.7411313, 'scale': 40758238.44851946}}
# enkidevs_commit
# {'norm': {'loc': 1475396648.9046817, 'scale': 3476145.301326224}}
# ethereum_go-ethereum
# {'cauchy': {'loc': 1548314565.60187, 'scale': 33875910.10348558}}
# pequet_alts-retracements
# {'uniform': {'loc': 1516478177.0, 'scale': 71628549.0}}
# getsentry_sentry
# {'powerlaw': {'a': 3.2746344181252693, 'loc': 1205603922.855752, 'scale': 409431902.14447343}}
# alowell_cosi_monitor
# {'powerlaw': {'a': 1.0514240704355284, 'loc': 1404596512.9571657, 'scale': 9247561.849296674}}
# tmtmtmtm_belgium-lachambre
# {'powerlaw': {'a': 2.834723832736981, 'loc': 1441039135.1933293, 'scale': 98324057.30914724}}
# Aman1531_redesigned-broccoli
# {'powerlaw': {'a': 1.0366515773747627, 'loc': 915167951.5842052, 'scale': 631078756.6126163}}
# Homebrew_homebrew-cask
# {'norm': {'loc': 1495507031.3763494, 'scale': 73973257.85862063}}
# AOEpeople_asdis
# {'norm': {'loc': 1315399045.0285792, 'scale': 55596069.404483125}}
# wordpress-mobile_WordPress-iOS
# {'norm': {'loc': 1472573909.9395967, 'scale': 76683435.40898226}}
# nodejs_node
# {'cauchy': {'loc': 1506349781.9216993, 'scale': 42810127.66383727}}
# cakephp_docs
# {'cauchy': {'loc': 1547422141.8069081, 'scale': 11415241.215480063}}
# everypolitician_everypolitician-data
# {'norm': {'loc': 1509115400.7596443, 'scale': 31419407.13798098}}
# TheBinitGhimire_WHOIScommits
# {'powerlaw': {'a': 1.300598105853969, 'loc': 1600200794.8741384, 'scale': 351262.1133885807}}
# ssbattousai_Cuda36
# {'gamma': {'a': 1.4744735988446935, 'loc': 1490069269.632247, 'scale': 175686.16208719928}}
# gitlab.com_quicla_platform/vendor/qcom-opensource/system/bt
# {'powerlaw': {'a': 5.240477447738197, 'loc': 1103012808.913632, 'scale': 512496331.6564721}}
# learn-co-students_py-lists-with-maps-data-science-intro-000
# {'gamma': {'a': 3509.5545979216618, 'loc': 947162265.3523091, 'scale': 169810.6073167003}}
# joomla_joomla-cms
# {'powerlaw': {'a': 1.8545074790873914, 'loc': 1097994802.5188742, 'scale': 517434830.6328529}}
# laravel_framework
# {'norm': {'loc': 1484634141.0983918, 'scale': 70942940.97399838}}
# alexcb_dumb
# {'cauchy': {'loc': 1557686539.4508114, 'scale': 398.67163376769327}}
# moodle_moodle
# {'norm': {'loc': 1332835970.565471, 'scale': 142501819.65012455}}
# wmst_wmidbot
# {'gamma': {'a': 2.2278143165627293, 'loc': 1393820731.3949385, 'scale': 20936909.175993882}}
# systemd_systemd
# {'norm': {'loc': 1462565957.4607775, 'scale': 112998261.42688935}}
# nosillnoboat_blocklist-ipsets
# {'powerlaw': {'a': 1.0171311000100096, 'loc': 1457641387.063861, 'scale': 2127132.6017374257}}
# everypolitician-scrapers_kenya-mzalendo
# {'cauchy': {'loc': 1486482855.7227712, 'scale': 3847828.215777034}}
# arvidn_libtorrent
# {'gamma': {'a': 21.60780927111486, 'loc': 795269975.3774576, 'scale': 23896535.346921213}}
# Killoso_autocommit
# {'powerlaw': {'a': 1.1646629123388914, 'loc': 1568095021.750187, 'scale': 401937.2498133739}}
# OCA_sale-workflow
# {'powerlaw': {'a': 4.277463290367482, 'loc': 1155714462.23662, 'scale': 459617832.893332}}
# jasperan_github-utils
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED powerlaw distribution (taking more than 120 seconds)
# {'norm': {'loc': 1544753203.3817809, 'scale': 38125.66620315077}}
# foren197316_blocklist-ipsets
# {'powerlaw': {'a': 1.8935105389546871, 'loc': 1437082697.9753666, 'scale': 8197148.670578014}}
# GitClock_GitClock
# {'powerlaw': {'a': 0.9580141548812953, 'loc': 1555095055.9734268, 'scale': 60521122.49232121}}
# apache_maven
# {'gamma': {'a': 2.8183690185298937, 'loc': 1062228888.303736, 'scale': 76001932.56913832}}
# mlz-ictrl_nicos
# {'cauchy': {'loc': 1507261845.3691847, 'scale': 29098487.20294088}}
# devopscripts_jenkins
# {'powerlaw': {'a': 0.904897460897079, 'loc': 1525748404.9999995, 'scale': 8236349.958625523}}
# Koha-Community_Koha
# {'powerlaw': {'a': 2.3202617639242256, 'loc': 963134055.5391803, 'scale': 651241893.6913538}}
# FirebirdSQL_firebird
# {'gamma': {'a': 2.5548520200339624, 'loc': 987951778.2736095, 'scale': 91454953.53957662}}
# dev-segal_dev-segal.github.io
# {'rayleigh': {'loc': 1605571701.4708574, 'scale': 697678.4163862828}}
# daedroza_aosp_development_sony8960_n
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# {'norm': {'loc': 1472387536.0400655, 'scale': 91968215.5677098}}
# babyshen_gcr.io
# {'powerlaw': {'a': 0.6741736236465394, 'loc': 1547018438.9999998, 'scale': 51957508.8269466}}
# mad-science_25445
# {'uniform': {'loc': 1461698275.0, 'scale': 854.0}}
# jakch79_test-src
# {'gamma': {'a': 19606.823103559393, 'loc': -19749893434.070587, 'scale': 1063585.623077001}}
# repo.or.cz_kdepim
# {'norm': {'loc': 1213242454.0291705, 'scale': 128985260.68318446}}
# mono_monodevelop
# {'powerlaw': {'a': 1.2068525303909334, 'loc': 1127483930.7740269, 'scale': 487849640.22597456}}
# pcdavid_org.eclipse.sirius
# {'gamma': {'a': 2.8999033944270183, 'loc': 1372374794.8685315, 'scale': 36315987.172338665}}
# gitlab.com_aosp_test2_platform/prebuilts/androidx/internal
# {'rayleigh': {'loc': 1556896643.5663602, 'scale': 6862755.640734765}}
# git-portage_git-portage
# {'rayleigh': {'loc': 996969882.3182522, 'scale': 169493507.14087296}}
# eyim_indy-e3b
# {'lognorm': {'s': 1.1457139622920947, 'loc': 1459587291.7984238, 'scale': 2658151.854785554}}
# thomasNDS_lbl
# {'uniform': {'loc': 1516351898.0, 'scale': 90349487.0}}
# randallho_laughing-barnacle
# {'uniform': {'loc': 1535277377.0, 'scale': 718.0}}
# adalenv_gitfiti_test
# {'norm': {'loc': 1516101435.609498, 'scale': 979434.9208868217}}
# git.kernel.org_pub_scm/public-inbox/vger.kernel.org/linux-wireless/0
# {'uniform': {'loc': 1170189584.0, 'scale': 413765384.0}}
# luisbtejada_test1
# {'powerlaw': {'a': 1.0115772970202173, 'loc': 1588847154.9198675, 'scale': 6029946.082376499}}
# git.kernel.org_pub_scm/public-inbox/lists.ozlabs.org/linuxppc-dev/0
# {'powerlaw': {'a': 3.616618265955821, 'loc': 340620692.41179097, 'scale': 1243363665.529221}}
# bitrig_bitrig
# {'powerlaw': {'a': 1.1905198610741792, 'loc': 813903910.2299263, 'scale': 672380882.7700751}}
# IThinkImOKAY_IThinkImOKAY
# {'lognorm': {'s': 0.7554766285520879, 'loc': 1601868397.4668603, 'scale': 1179487.1123841864}}
# marcomep_subversion
# {'powerlaw': {'a': 1.3379223872826935, 'loc': 951831098.4145054, 'scale': 396774332.5854949}}
# jenkinsci_git-client-plugin
# WARNING:root:SKIPPED rayleigh distribution (taking more than 120 seconds)
# {'gamma': {'a': 17.49486513961834, 'loc': 1320261015.8373923, 'scale': 11566697.25594094}}
# repo.or.cz_mono
# {'norm': {'loc': 1145998183.1527112, 'scale': 70917512.17943683}}
# strigazi_athena
# {'powerlaw': {'a': 1.4187428913975777, 'loc': 1407342863.233224, 'scale': 191864722.55804643}}
# jdzs1_b
# {'gamma': {'a': 1.2594361359852009, 'loc': 1542292338.2761168, 'scale': 6086546.0732391905}}
# bert_pcb
# {'cauchy': {'loc': 1302424684.8111846, 'scale': 26659053.325928032}}
# Zimbra_zm-mailbox
# {'powerlaw': {'a': 1.040218111445673, 'loc': 1124223307.4104338, 'scale': 490728024.5895668}}
# hasura-imad_imad-2016-app
# {'rayleigh': {'loc': 1472950783.1704032, 'scale': 3915733.4491313617}}
# cunzhen99_free99
# {'cauchy': {'loc': 1507789191.5586498, 'scale': 1379190.6073322985}}
# preda-bogdan_test_gitfity
# {'powerlaw': {'a': 0.9222854788327564, 'loc': 1529830799.9999995, 'scale': 25732098.872393012}}
# processing_processing
# {'norm': {'loc': 1277569739.5490665, 'scale': 129673704.68887834}}
# git.kernel.org_pub_scm/public-inbox/kvack.org/linux-mm/0
# {'norm': {'loc': 1379747176.850386, 'scale': 153574411.63499317}}
# roytam1_mozilla-cvs-history
# {'gamma': {'a': 1.8124387231800556, 'loc': 887289850.296015, 'scale': 94158004.00290802}}
# jacob-carlborg_llvm-svn
# {'powerlaw': {'a': 1.4547117559182503, 'loc': 991188097.8852296, 'scale': 548060801.1161036}}
# git.savannah.gnu.org_git_emacs/elpa
# {'norm': {'loc': 1209820244.1817427, 'scale': 218530749.69333914}}
# twbs_bootstrap
# {'gamma': {'a': 364.79161737973186, 'loc': -439218880.1630101, 'scale': 5119132.543902962}}
# hhc97_commits2
# {'uniform': {'loc': 1593712896.0, 'scale': 53911.0}}
# Jackeagle_kernel_msm-3.18
# WARNING:root:SKIPPED cauchy distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED chi2 distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED gamma distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED powerlaw distribution (taking more than 120 seconds)
# {'norm': {'loc': 1457232282.1479578, 'scale': 113786572.51949994}}
# openhab_openhab-addons
# {'powerlaw': {'a': 1.9592808912577349, 'loc': 1266630050.1419487, 'scale': 356892561.24337626}}
# firehol_blocklist-ipsets
# {'cauchy': {'loc': 1448212459.681375, 'scale': 1082533.5792856733}}
# OriginProtocol_origin
# {'cauchy': {'loc': 1521320907.8412268, 'scale': 40117189.49271332}}
# kubernetes_kubernetes
# {'gamma': {'a': 6.020489621054338, 'loc': 1373416132.7135556, 'scale': 20577984.222007252}}
# liancastellon_jd-trunk
# {'gamma': {'a': 1036.36099465726, 'loc': -1710851272.594852, 'scale': 2957879.8182187304}}
# i17c_ecode
# {'gamma': {'a': 1.6634601826278164, 'loc': 1443178484.1490564, 'scale': 25479571.57484619}}
# gitlab.com_jtojnar_clubpenguinwiki
# {'cauchy': {'loc': 1281357960.15494, 'scale': 25967317.74444508}}
# 3nodedev_pole
# {'uniform': {'loc': 1451937600.0, 'scale': 5097600.0}}
# samuelc624_sp17
# {'expon': {'loc': 0.0, 'scale': 6265554.443950457}}
# JacksonChen666_too-many-commits
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED powerlaw distribution (taking more than 120 seconds)
# {'gamma': {'a': 1.3423148137465644, 'loc': 1595261542.9514341, 'scale': 57686.70487246865}}
# kmtos_DataFormats-JetReco
# {'norm': {'loc': 1234180320.4416595, 'scale': 63994199.34586522}}
# Anon-Exploiter_make-me-first-another
# {'cauchy': {'loc': 1600840106.939869, 'scale': 29782.951916644903}}
# yanzaihuai_ogate
# {'cauchy': {'loc': 1483816522.2544363, 'scale': 1892996.4132859516}}
# Awan_ops
# {'powerlaw': {'a': 0.5827690431536496, 'loc': 1608582523.0493908, 'scale': 585512.1546307688}}
# freebsd_freebsd
# WARNING:root:SKIPPED cauchy distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED chi2 distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED gamma distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED powerlaw distribution (taking more than 120 seconds)
# {'norm': {'loc': 1006735596.5944622, 'scale': 315999208.9012725}}
# wikimedia_mediawiki-extensions-Wikibase
# {'gamma': {'a': 2.536787216795976, 'loc': 1329375130.773795, 'scale': 42968087.816184245}}
# syuu1228_openbsd-src
# {'powerlaw': {'a': 1.133450498091035, 'loc': 813962181.8889216, 'scale': 527500031.11107904}}
# pbaffiliate4_repoForSettings
# {'rayleigh': {'loc': 1536372696.876627, 'scale': 13652186.193146173}}
# andylolz_ynmp-contrib
# {'uniform': {'loc': 1521209633.0, 'scale': 1640.0}}
# tmtmtmtm_armenia-assembly
# {'gamma': {'a': 22.591710899376917, 'loc': 1440774644.8237357, 'scale': 2870495.6361428425}}
# Waffiliate_repoForSynchOut
# {'powerlaw': {'a': 0.7954486674965423, 'loc': 1539257347.9998498, 'scale': 76346068.84595174}}
# odoo_odoo
# {'cauchy': {'loc': 1345320978.1916108, 'scale': 53636240.59000321}}
# test-organization-kkjeer_bot-validation
# {'cauchy': {'loc': 1598578328.6261368, 'scale': 6373415.543293075}}
# labzero_lunch
# {'gamma': {'a': 265.43817709412895, 'loc': 735326527.6833477, 'scale': 2881450.300799569}}
# object-logics_isabelle_para
# {'cauchy': {'loc': 1313907957.4684896, 'scale': 95479452.65122959}}
# learn-co-curriculum_python-for-loops-lab
# {'lognorm': {'s': 0.06920245145139242, 'loc': 1400375506.856812, 'scale': 142778528.31965792}}
# gitorious.org_pkgsrc/mainline
# {'powerlaw': {'a': 1.6019825700371757, 'loc': 871916361.533973, 'scale': 369899227.4769525}}
# repo.or.cz_vdsm
# {'norm': {'loc': 1466975172.1764672, 'scale': 68680448.98788916}}
# kraj_glibc
# {'gamma': {'a': 428.3859128662398, 'loc': -3401903872.314289, 'scale': 10749619.258291736}}
# wordpress-mobile_WordPress-Android
# {'powerlaw': {'a': 2.0880721288753836, 'loc': 1215804653.223988, 'scale': 399916648.7760141}}
# opendaylight_openflowplugin
# {'powerlaw': {'a': 1.4155979645445256, 'loc': 1374279603.1118493, 'scale': 239766091.88815182}}
# gradle_gradle
# {'cauchy': {'loc': 1510176419.9654508, 'scale': 47896023.34175579}}
# K5371_4
# {'expon': {'loc': 0.0, 'scale': 5510265.436934096}}
# beaulebens_keyring
# WARNING:root:SKIPPED cauchy distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED chi2 distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED powerlaw distribution (taking more than 120 seconds)
# {'norm': {'loc': 1336751449.548819, 'scale': 52662822.117018916}}
# mamedev_mame
# ...
# anuditnagar_millionaire
# {'powerlaw': {'a': 0.054484863220252616, 'loc': 1554966932.9999995, 'scale': 83514.6765052408}}
# openSUSE_kernel-source
# {'powerlaw': {'a': 13.11666004039142, 'loc': -419140437.9674196, 'scale': 2035227617.1895418}}
# bitpay_bitcore
# {'rayleigh': {'loc': 1372500647.3160205, 'scale': 90927785.79985675}}
# crawl_crawl
# {'rayleigh': {'loc': 1184231192.5087392, 'scale': 163953403.7838291}}
# TestToJava_covid-19-india
# {'powerlaw': {'a': 1.2650866368188287, 'loc': 1585738372.9726734, 'scale': 28786141.02732661}}
# Phantom-Blue_phantom-blue
# {'gamma': {'a': 842.6590104097479, 'loc': 491860554.13535583, 'scale': 1250639.3933006949}}
# codeix_z3c.recipe.dev
# {'norm': {'loc': 1131159536.849867, 'scale': 93171403.89854069}}
# jocelyn-draft_ignore
# {'cauchy': {'loc': 1511207466.1184661, 'scale': 1029400.9348409991}}
# guadguadt_up
# {'powerlaw': {'a': 0.8132640580914337, 'loc': 1554707120.9999995, 'scale': 42584139.160658255}}
# EugeneYilia_EugeneSignIn
# {'uniform': {'loc': 1532982272.0, 'scale': 4439998.0}}
# biorealize_biorealize.github.io
# {'cauchy': {'loc': 1581264130.4928648, 'scale': 754494.2249353359}}
# eclipse_linuxtools
# {'cauchy': {'loc': 1383046718.543713, 'scale': 21479130.256127514}}
# zm9913_maven-db-plugin
# {'norm': {'loc': 1288304092.9110177, 'scale': 20658757.11266998}}
# jeongminkim_jeongminkim.github.com
# {'gamma': {'a': 539.3881616068402, 'loc': 1526790979.4120293, 'scale': 36824.78907944437}}
# simonAllier_benoit-exp-result
# {'cauchy': {'loc': 1445080947.6714306, 'scale': 1881317.30055069}}
# dolphin-emu_dolphin
# {'cauchy': {'loc': 1536742799.0661545, 'scale': 34303301.72122583}}
# donno2048_stretch-test
# {'norm': {'loc': 1601661302.7032423, 'scale': 63436.89347004842}}
# freebsd_freebsd-doc
# {'gamma': {'a': 4.742035684484936, 'loc': 721292911.0634677, 'scale': 94751126.8410058}}
# pohly_chromiumos-overlays-board-overlays
# {'powerlaw': {'a': 1.2528525722298876, 'loc': 1265008306.189406, 'scale': 300006474.81059444}}
# ucscGenomeBrowser_kent
# {'rayleigh': {'loc': 975981605.5789415, 'scale': 245721810.3295606}}
# scylladb_scylla
# {'norm': {'loc': 1519162024.9689589, 'scale': 53540703.73290753}}
# gitlab.com_tikiwiki_tiki
# {'powerlaw': {'a': 1.4901243684687708, 'loc': 1033442039.6127236, 'scale': 579968850.3872774}}
# btopt5_idepairline
# {'powerlaw': {'a': 1.1453790842374985, 'loc': 1551947724.152052, 'scale': 6557365.847948091}}
# repl-electric_sonic-pi-history
# {'uniform': {'loc': 1413570050.0, 'scale': 124573125.0}}
# kszucs_crossbow
# {'powerlaw': {'a': 1.7353509981904924, 'loc': 1526851219.3715782, 'scale': 83858706.62846512}}
# openstack_horizon
# {'gamma': {'a': 56.198597198348025, 'loc': 1010355905.8047009, 'scale': 7553817.505655849}}
# auto-program_vendor
# {'rayleigh': {'loc': 1350034991.484967, 'scale': 102560300.66248442}}
# Kitware_CMake
# {'norm': {'loc': 1280797977.8641264, 'scale': 189758899.40611908}}
# jruby_jruby
# {'powerlaw': {'a': 1.4348363573641443, 'loc': 994073162.0155993, 'scale': 621414604.9844146}}
# git.kernel.org_pub_scm/public-inbox/vger.kernel.org/lkml/4
# {'powerlaw': {'a': 1.170674139094229, 'loc': 1420413062.0344062, 'scale': 52135955.67101896}}
# geos4s_realtimegis
# {'powerlaw': {'a': 0.8598433398245634, 'loc': 1520158578.9999995, 'scale': 23328304.618047122}}
# bloomberg_chromium.bb
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# {'powerlaw': {'a': 4.673954640279915, 'loc': 618760070.8594165, 'scale': 996727749.1405928}}
# civicrm_civicrm-core
# {'rayleigh': {'loc': 1337855637.1131928, 'scale': 104211510.42052373}}
# ncatlab_nlab-content-deprecated
# {'expon': {'loc': 1504202198.0, 'scale': 36393.27429962158}}
# swedishtechevents_swedishtechevents.github.io
# {'cauchy': {'loc': 1591809083.5630846, 'scale': 5135531.00635335}}
# ampproject_amphtml
# {'norm': {'loc': 1537211033.9889286, 'scale': 44403064.61678192}}
# binary-com_binary-static
# {'powerlaw': {'a': 1.5499823579226117, 'loc': 1395631222.1346164, 'scale': 219984337.90692538}}
# sipwise_ngcp-panel
# {'cauchy': {'loc': 1474326977.2146988, 'scale': 25190282.159340873}}
# ssbattousai_Cuda12
# {'powerlaw': {'a': 1.021111992925134, 'loc': 1458836915.8971868, 'scale': 4352126.437226158}}
# Cutthroat413_markdown-portfolio
# {'powerlaw': {'a': 1.6889251926517201, 'loc': 1518528632.5814235, 'scale': 96303847.4185768}}
# project-draco-hr_consulo
# {'norm': {'loc': 1262754985.419123, 'scale': 79064835.55454648}}
# chromium_chromium
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# {'cauchy': {'loc': 1500772138.7301419, 'scale': 33517748.05359839}}
# google_skia-buildbot
# {'norm': {'loc': 1538715776.4426153, 'scale': 44804453.645661354}}
# ICGC-TCGA-PanCancer_ceph_transfer_ops
# {'cauchy': {'loc': 1457094117.841208, 'scale': 4905805.390347727}}
# gitlab.freedesktop.org_mesa_mesa
# {'powerlaw': {'a': 3.384074000382604, 'loc': 856537925.2250724, 'scale': 762896834.7163329}}
# openbsd_ports
# {'norm': {'loc': 1282495677.6930754, 'scale': 169117238.29842302}}
# girish-io_RepoWithALotOfCommits
# {'gamma': {'a': 1.7371055106943945, 'loc': 1610559959.597499, 'scale': 8532.870285294259}}
# Arkhtyi_Discrete-structures
# {'expon': {'loc': 0.0, 'scale': 6630093.957350273}}
# pfsense_FreeBSD-ports
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# {'powerlaw': {'a': 1.6304305430809252, 'loc': 750352488.8234514, 'scale': 865198588.1765486}}
# gitorious.org_openoffice/mirror
# {'norm': {'loc': 1118516821.095349, 'scale': 73273473.1535554}}
# surmon-china_nothing
# {'cauchy': {'loc': 1461534842.278851, 'scale': 68009.47876428283}}
# ClashProducts_wordpress553
# {'norm': {'loc': 1363759820.3617098, 'scale': 133609209.6657023}}
# ywei2015_myproject
# {'exponpow': {'b': 0.1552438198515752, 'loc': -6.085697481132671e-19, 'scale': 860317223.2164377}}
# hakrtech_openbsd-src0-test
# {'powerlaw': {'a': 1.1277546700420071, 'loc': 813979550.7178316, 'scale': 707885632.4089706}}
# freeCodeCamp_freeCodeCamp
# {'cauchy': {'loc': 1539920304.2653997, 'scale': 23216078.430776082}}
# facebook_buck
# {'powerlaw': {'a': 2.4320334168701314, 'loc': 1223420023.4218524, 'scale': 392106943.57814807}}
# kerim_microblog
# {'powerlaw': {'a': 1.3960496696493463, 'loc': 1517769450.8107257, 'scale': 26641731.18927436}}
# electron_i18n
# {'powerlaw': {'a': 0.9780673699369482, 'loc': 1494682487.1416812, 'scale': 119216081.85831946}}
# repo.or.cz_netbsd-mini2440
# {'gamma': {'a': 1213.07888143728, 'loc': -3836232706.9089994, 'scale': 4001288.029494905}}
# NixOS_nixpkgs
# {'powerlaw': {'a': 2.7034342256416988, 'loc': 1024422663.7976222, 'scale': 590956105.20614}}
# ebezault_EiffelStudio
# {'norm': {'loc': 1094306849.048268, 'scale': 165665599.43316028}}
# enricemcorro_enricemcorro
# {'cauchy': {'loc': 1584028034.6124716, 'scale': 267246.66481366515}}
# openshift_origin
# {'gamma': {'a': 905.8468392773648, 'loc': -66556364.496377215, 'scale': 1752071.1665350785}}
# ssbattousai_Cuda13
# {'norm': {'loc': 1461070295.8431556, 'scale': 1192416.265735888}}
# OSGeo_grass
# {'norm': {'loc': 1379010359.8997438, 'scale': 95982937.66228536}}
# wikimedia_apps-android-wikipedia
# {'rayleigh': {'loc': 1376734982.511176, 'scale': 84043166.6986588}}
# LambdaSchool_Graphs
# {'gamma': {'a': 840.2319662925231, 'loc': 940057959.3399155, 'scale': 745827.9435471662}}
# git.kernel.org_pub_scm/public-inbox/vger.kernel.org/git
# {'exponpow': {'b': 0.12974608646013489, 'loc': 1466030511.9999998, 'scale': 4651129.7213635}}
# edquist_osg-twiki-backup
# {'exponpow': {'b': 0.86530694887741, 'loc': 1526327213.9999998, 'scale': 15108.62335719552}}
# 0xrabin_commitsbro
# {'cauchy': {'loc': 1605514745.4162807, 'scale': 5874.225635951088}}
# Intel_luv-yocto
# {'norm': {'loc': 1418778281.4532046, 'scale': 123899351.25013658}}
# stoupoun_p2-breathe
# {'rayleigh': {'loc': 1376924275.3878047, 'scale': 59800160.48228903}}
# eugene-matvejev_1kkk-commit-repository
# {'norm': {'loc': 1487901065.750302, 'scale': 146316.3168021166}}
# lammps_lammps
# {'gamma': {'a': 43.454404950814734, 'loc': 671256655.5944052, 'scale': 16579079.78192497}}
# jasoncalabrese_indy-e4c
# {'powerlaw': {'a': 1.0214668895695798, 'loc': 1488207059.3150706, 'scale': 19875496.684929453}}
# kraj_binutils-gdb
# {'gamma': {'a': 1723803.17557549, 'loc': -252714990192.44165, 'scale': 147304.95068602514}}
# udacity_frontend-nanodegree-resume
# {'norm': {'loc': 1486208598.121576, 'scale': 41307235.49448251}}
# mcmult_lustre
# {'cauchy': {'loc': 1374986433.9636383, 'scale': 72889929.85077174}}
# ikasunsa_www
# {'rayleigh': {'loc': 1529578553.7640374, 'scale': 9684139.277482903}}
# ishvaram_hackygbit
# {'cauchy': {'loc': 1532579139.0562065, 'scale': 10276573.802630825}}
# tmtmtmtm_nigeria-national-assembly
# {'rayleigh': {'loc': 1472284300.374544, 'scale': 27275520.67263411}}
# 8emezzo_8emezzo.github.io
# {'powerlaw': {'a': 0.9858873922244094, 'loc': 1555327120.9999998, 'scale': 19470573.357376788}}
# appcelerator_titanium_mobile
# {'gamma': {'a': 2.7198704362688932, 'loc': 1241414467.6439915, 'scale': 56688011.993898734}}
# crowbar_crowbar-core
# {'gamma': {'a': 1.65070550813017, 'loc': 1310828340.3937676, 'scale': 64449725.886450425}}
# radhaisme_anticlergygang.github.io
# {'gamma': {'a': 391.6842619086673, 'loc': 1471382928.3310862, 'scale': 131510.64073380706}}
# AmartyaU_WordPress
# {'norm': {'loc': 1366029838.380952, 'scale': 130992241.04767416}}
# DragonFlyBSD_DPorts
# {'powerlaw': {'a': 0.8113311862623793, 'loc': 1351511974.9999998, 'scale': 264075137.28760493}}
# tmtmtmtm_tanzania-parliament
# {'powerlaw': {'a': 3.4463940947981566, 'loc': 1430126234.5630195, 'scale': 107150876.7006476}}
# EnkiChen_webrtc
# {'cauchy': {'loc': 1511752709.6651638, 'scale': 11414562.274921108}}
# jenkins-x_default-environment-charts
# {'norm': {'loc': 1566178481.2220974, 'scale': 19061563.413030744}}
# eigenteam_eigen-git-mirror
# {'cauchy': {'loc': 1551706484.0554383, 'scale': 14179610.62626419}}
# gentoo_gentoo-portage-rsync-mirror
# {'powerlaw': {'a': 1.4152777072882436, 'loc': 1356587565.7567496, 'scale': 251100460.24325043}}
# dimagi_commcare-hq
# {'powerlaw': {'a': 1.9832956767207965, 'loc': 1229933418.350296, 'scale': 384771712.64970404}}
# apple_swift
# {'cauchy': {'loc': 1478885028.358523, 'scale': 65109907.312812716}}
# root-project_root
# {'powerlaw': {'a': 2.2644080294768356, 'loc': 899527284.4532282, 'scale': 716134519.5467739}}
# fharbe_unix-history-repo
# {'norm': {'loc': 562759176.7799617, 'scale': 157838818.9703976}}
# ILIAS-eLearning_ILIAS
# {'powerlaw': {'a': 1.2142107696221798, 'loc': 1026546941.376441, 'scale': 588866978.6034727}}
# ckeditor_ckeditor-dev
# {'cauchy': {'loc': 1518178746.3098865, 'scale': 40667519.22151586}}
# spryker_demoshop
# {'cauchy': {'loc': 1547757073.0864873, 'scale': 26813795.840010125}}
# invent.kde.org_system_dolphin
# {'norm': {'loc': 1196978486.9030027, 'scale': 163132066.61615723}}
# git.savannah.gnu.org_git_mediagoblin
# {'cauchy': {'loc': 1502298535.2889352, 'scale': 30496578.806029074}}
# NickeyWoo_wiki
# {'cauchy': {'loc': 1423709325.9059067, 'scale': 8272049.804615384}}
# gitorious.org_netbeans/main-silver
# {'cauchy': {'loc': 1229035146.8225367, 'scale': 35596035.380143575}}
# dingpengyu_screenReaderTranslations
# {'powerlaw': {'a': 2.3418473565945144, 'loc': 1172844605.8686857, 'scale': 369512460.1313188}}
# mongodb_mongo
# {'norm': {'loc': 1369722470.7694397, 'scale': 137318178.86718774}}
# apache_lucene-solr
# {'gamma': {'a': 467.33534657875407, 'loc': -1141238605.7068515, 'scale': 5392984.848610837}}
# tootsuite_mastodon
# {'powerlaw': {'a': 1.4878260530372107, 'loc': 1456003384.660427, 'scale': 159767664.3395732}}
# WenhuaChang_openSUSE-grub2
# {'cauchy': {'loc': 1300746304.7944317, 'scale': 66787894.30437288}}
# jpark2383_MP2
# {'expon': {'loc': 0.0, 'scale': 10150606.451034768}}
# ZIDAN44_linux-stable
# {'norm': {'loc': 1264448848.3283775, 'scale': 70717487.26209868}}
# teisam_teisam.github.io
# {'powerlaw': {'a': 1.0011350251429416, 'loc': 1519126082.2809467, 'scale': 25264238.71906674}}
# gentoo_gentoo
# WARNING:root:SKIPPED exponpow distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED lognorm distribution (taking more than 120 seconds)
# WARNING:root:SKIPPED powerlaw distribution (taking more than 120 seconds)
# {'gamma': {'a': 4.0367418411773475, 'loc': 951162626.1461525, 'scale': 80455553.6177811}}
# git.kernel.org_pub_scm/public-inbox/vger.kernel.org/lkml/2
# {'powerlaw': {'a': 1.1218921065593133, 'loc': 1267474996.5952194, 'scale': 90369853.40478115}}
# MicrosoftDocs_azure-docs
# {'powerlaw': {'a': 2.155745585001586, 'loc': 1325381979.1722524, 'scale': 288433427.8279251}}
# vanzin_jEdit
# {'norm': {'loc': 1207937923.9362464, 'scale': 125059551.65139548}}
# gitlab.com_szzdlab_ntdtv
# {'norm': {'loc': 1571036684.6102405, 'scale': 1009216.330969232}}
# varunsridharan_fun-automated-commit
# {'norm': {'loc': 1594193126.1891148, 'scale': 27087.881710051915}}
# escottdexcom_indy-e1g
# {'powerlaw': {'a': 1.0651227766952331, 'loc': 1470046917.4322758, 'scale': 5110549.487612851}}
# opencollab_scilab
# {'norm': {'loc': 1299839809.6716213, 'scale': 117189930.51416446}}
# daenuprobst_covid19-cases-switzerland
# {'powerlaw': {'a': 1.1927240322013015, 'loc': 1584017144.1330895, 'scale': 31184521.86691047}}
# jspaleta_why
# {'uniform': {'loc': 1590626483.0, 'scale': 1908.0}}
# samba-team_samba
# {'cauchy': {'loc': 1225904919.4545474, 'scale': 106116214.36503313}}
# marco-c_gecko-dev-comments-removed
# {'cauchy': {'loc': 1578077946.1275282, 'scale': 242881.08131655212}}
# jthub_ega-file-transfer-to-collab-4-jtracker
# {'exponpow': {'b': 0.8675349944877291, 'loc': 1498855918.9999998, 'scale': 2375017.676407479}}
# xen-project_xen
# {'norm': {'loc': 1291659114.1579826, 'scale': 152434867.66680095}}
# geos4s_18w856162
# {'powerlaw': {'a': 1.0383238148122595, 'loc': 1543304257.0225184, 'scale': 46579069.97748171}}
# batchpause_PAUSE-git
# {'powerlaw': {'a': 0.8155789231771902, 'loc': 1333188513.9999998, 'scale': 282470209.1135315}}
# comitterman_testrepo
# {'norm': {'loc': 1474327809.6962562, 'scale': 20457.362974953066}}
# gitlab.com_THT-INC_git-plugin-tests
# {'rayleigh': {'loc': 1496394951.487016, 'scale': 46943046.89892453}}
# alisw_AliPhysics
# {'norm': {'loc': 1337443847.299195, 'scale': 144655768.88452733}}
# gitlab.com_techdemocracyresearch_mosip/mosip/registration-old
# {'rayleigh': {'loc': 1534313919.2013474, 'scale': 19118989.52353764}}
# Unity-Technologies_ScriptableRenderPipeline
# {'powerlaw': {'a': 3.22635204525473, 'loc': 1367013632.4738717, 'scale': 248524395.5268476}}
# gitlab.com_quicla_platform/packages/apps/Mms
# {'gamma': {'a': 41.52533351885216, 'loc': 887192203.7374018, 'scale': 13473439.269117229}}
# xcaq_xcaq
# {'powerlaw': {'a': 0.8104260859515318, 'loc': 1594547751.9999998, 'scale': 20958129.88811458}}
# spirosmastorakis_CFN
# {'gamma': {'a': 1.6522584269020226, 'loc': 1155982402.457314, 'scale': 104095934.60579208}}
# git.kernel.org_pub_scm/public-inbox/lists.infradead.org/linux-arm-kernel/0
# {'powerlaw': {'a': 1.5409001150435095, 'loc': 1234271994.901966, 'scale': 317036671.84710574}}
# m1ha5_testing
# {'powerlaw': {'a': 1.483247591212018, 'loc': 1563678604.7075415, 'scale': 5989711.330761781}}
# crosswalk-project_blink-crosswalk
# {'norm': {'loc': 1313023776.3467717, 'scale': 84684254.63237098}}
# starseeker_git_conv_test
# {'cauchy': {'loc': 1284163568.7956884, 'scale': 143317119.56610173}}
# asimamalani_gitfiti
# {'rayleigh': {'loc': 1553391321.2721143, 'scale': 6674896.456039705}}
# chapel-lang_chapel
# {'powerlaw': {'a': 1.2245583077867703, 'loc': 1074460906.4420462, 'scale': 541160037.558434}}
# idevat_trac-tags-plugin
# {'norm': {'loc': 1306825703.2433383, 'scale': 80950680.27830659}}
# learn-co-students_debugging-with-pry-v-000
# {'norm': {'loc': 1539878454.0170293, 'scale': 33415753.79115802}}
# dotnet_roslyn
# {'powerlaw': {'a': 1.4835657904050157, 'loc': 1394925150.8486702, 'scale': 220369983.15132996}}
# Homebrew_homebrew-core
# {'norm': {'loc': 1520684716.049252, 'scale': 63307033.072831064}}
# boostorg_boost
# {'rayleigh': {'loc': 950337148.3259642, 'scale': 191851618.52610755}}
# hedgespin_sensor_data
# {'powerlaw': {'a': 0.8485206006414929, 'loc': 1523448740.9999995, 'scale': 92993579.17356086}}
# mleoking_PhET
# {'norm': {'loc': 1254322581.3062484, 'scale': 76294585.1078383}}
# simonpcook_llvm-clang-submodulerepo

# %%
print(len(dists))
# Out:
# 1000

# %%
#commented out to avoid tampering with file accidentally

f = open('rawdistresults.csv', 'w')
f.write('project,distribution,loc,scale\n')
for dist, project in zip(dists, projects):
    dtb = list(dist.keys())[0]
    sts = list(list(dist.values())[0].values())
    line = project + ',' + dtb + ',' + str(sts[0]) + ',' + str(sts[1]) + '\n'
    f.write(line)
f.close()

# %%
best_fits = pd.read_csv('rawdistresults.csv')
best_fits.head()
# Out:
#                                      project distribution           loc  \
# 0                                  ruby_ruby         norm  1.357944e+09
# 1  learn-co-students_activerecord-crud-v-000     rayleigh  1.503046e+09
# 2                          keum_data_display     powerlaw  1.382210e+00
# 3                         struan_netherlands     powerlaw  2.063059e+00
# 4                              geovas01_man4     powerlaw  2.666686e-01
#
#           scale
# 0  1.509701e+08
# 1  3.305963e+07
# 2  1.395732e+09
# 3  1.441784e+09
# 4 -1.531846e-18

# %%
#I was going to plot this but they're all cauchy 
distribution_counts = best_fits['distribution'].value_counts()
print(distribution_counts)
# Out:
# powerlaw    303
# norm        206
# cauchy      165
# gamma       143
# rayleigh    101
# uniform      30
# expon        28
# lognorm      12
# exponpow     11
# chi2          1
# Name: distribution, dtype: int64

# %%
best_fits.plot.scatter(x = 'loc', y = 'scale')
# Out:
# <AxesSubplot:xlabel='loc', ylabel='scale'>

# %% [markdown]
# ### [5.3] Develop static and interactive visualizations to demonstrate the findings.
